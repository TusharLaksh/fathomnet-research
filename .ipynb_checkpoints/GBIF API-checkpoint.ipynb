# %%
# !pip install fathomnet
# Out:
# Collecting fathomnet
#   Using cached fathomnet-0.6.0-py3-none-any.whl (21 kB)
# Collecting coco-lib<0.2.0,>=0.1.2 (from fathomnet)
#   Using cached coco_lib-0.1.3-py3-none-any.whl (5.4 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.4 (from fathomnet)
#   Using cached dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml<5.0.0,>=4.6.0 in c:\programdata\anaconda3\lib\site-packages (from fathomnet) (4.6.3)
# Collecting progressbar2<4.0.0,>=3.37.0 (from fathomnet)
#   Using cached progressbar2-3.55.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from fathomnet) (2.26.0)
# Collecting marshmallow<4.0.0,>=3.3.0 (from dataclasses-json<0.6.0,>=0.5.4->fathomnet)
#   Using cached marshmallow-3.19.0-py3-none-any.whl (49 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1 (from dataclasses-json<0.6.0,>=0.5.4->fathomnet)
#   Using cached marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.4->fathomnet)
#   Using cached typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting python-utils>=2.3.0 (from progressbar2<4.0.0,>=3.37.0->fathomnet)
#   Using cached python_utils-3.5.2-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from progressbar2<4.0.0,>=3.37.0->fathomnet) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->fathomnet) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->fathomnet) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->fathomnet) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->fathomnet) (3.2)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.4->fathomnet) (21.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\tushar\appdata\roaming\python\python39\site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.4->fathomnet) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\tushar\appdata\roaming\python\python39\site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.4->fathomnet) (4.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.4->fathomnet) (3.0.4)
# Installing collected packages: typing-inspect, python-utils, progressbar2, marshmallow, marshmallow-enum, dataclasses-json, coco-lib, fathomnet
# Successfully installed coco-lib-0.1.3 dataclasses-json-0.5.7 fathomnet-0.6.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 progressbar2-3.55.0 python-utils-3.5.2 typing-inspect-0.8.0

# %%
# !pip install pygbif
# Out:
# Collecting pygbif
#   Downloading pygbif-0.6.2-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.5/61.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>2.7 in c:\programdata\anaconda3\lib\site-packages (from pygbif) (2.26.0)
# Collecting requests-cache (from pygbif)
#   Downloading requests_cache-1.0.1-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.7/58.7 kB 1.6 MB/s eta 0:00:00
# Collecting geojson-rewind (from pygbif)
#   Downloading geojson_rewind-1.0.3-py3-none-any.whl (5.0 kB)
# Collecting geomet (from pygbif)
#   Downloading geomet-1.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: appdirs>=1.4.3 in c:\programdata\anaconda3\lib\site-packages (from pygbif) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\tushar\appdata\roaming\python\python39\site-packages (from pygbif) (3.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>2.7->pygbif) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>2.7->pygbif) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>2.7->pygbif) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>2.7->pygbif) (3.2)
# Requirement already satisfied: click in c:\users\tushar\appdata\roaming\python\python39\site-packages (from geomet->pygbif) (8.0.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from geomet->pygbif) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tushar\appdata\roaming\python\python39\site-packages (from matplotlib->pygbif) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (1.3.1)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (21.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pygbif) (2.8.2)
# Requirement already satisfied: attrs>=21.2 in c:\users\tushar\appdata\roaming\python\python39\site-packages (from requests-cache->pygbif) (21.4.0)
# Collecting cattrs>=22.2 (from requests-cache->pygbif)
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tushar\appdata\roaming\python\python39\site-packages (from requests-cache->pygbif) (2.5.0)
# Collecting url-normalize>=1.4 (from requests-cache->pygbif)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting exceptiongroup (from cattrs>=22.2->requests-cache->pygbif)
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: colorama in c:\users\tushar\appdata\roaming\python\python39\site-packages (from click->geomet->pygbif) (0.4.4)
# Installing collected packages: url-normalize, geojson-rewind, exceptiongroup, geomet, cattrs, requests-cache, pygbif
# Successfully installed cattrs-22.2.0 exceptiongroup-1.1.1 geojson-rewind-1.0.3 geomet-1.0.0 pygbif-0.6.2 requests-cache-1.0.1 url-normalize-1.4.3

# %%
# !pip install gbif
# Out:
# Collecting gbif
#   Downloading gbif-0.1.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting restkit (from gbif)
#   Downloading restkit-4.2.2.tar.gz (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting http-parser>=0.8.3 (from restkit->gbif)
#   Downloading http-parser-0.9.0.tar.gz (167 kB)
#      ------------------------------------- 167.1/167.1 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting socketpool>=0.5.3 (from restkit->gbif)
#   Downloading socketpool-0.5.3.tar.gz (9.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: gbif, restkit, http-parser, socketpool
#   Building wheel for gbif (setup.py): started
#   Building wheel for gbif (setup.py): finished with status 'done'
#   Created wheel for gbif: filename=gbif-0.1.0-py3-none-any.whl size=4017 sha256=2373e096a76459d7ed04c132b194197db9044d6a0e009a50c8d57e6abe6729e1
#   Stored in directory: c:\users\tushar\appdata\local\pip\cache\wheels\e4\58\35\d85c174ebd80734119d0024ece3b0248b931cd30300a4d1d30
#   Building wheel for restkit (setup.py): started
#   Building wheel for restkit (setup.py): finished with status 'done'
#   Created wheel for restkit: filename=restkit-4.2.2-py3-none-any.whl size=49499 sha256=e992f33dbf53dc57badb0808a14ebda14beddbf95dc7852c5181092994e5cbfb
#   Stored in directory: c:\users\tushar\appdata\local\pip\cache\wheels\f8\9b\e7\e1bfbe1a3621cce69cebc76d25f04ee1a9c626dc9ffd30e770
#   Building wheel for http-parser (setup.py): started
#   Building wheel for http-parser (setup.py): finished with status 'done'
#   Created wheel for http-parser: filename=http_parser-0.9.0-cp39-cp39-win_amd64.whl size=71290 sha256=6111bfb36e74a2e6ab08aaddce53086eac5c56af588895d635f5c2ec2d143ed8
#   Stored in directory: c:\users\tushar\appdata\local\pip\cache\wheels\44\5a\7b\6022a5d680cd105345913f051917e62ac45684d8f496ce6eec
#   Building wheel for socketpool (setup.py): started
#   Building wheel for socketpool (setup.py): finished with status 'done'
#   Created wheel for socketpool: filename=socketpool-0.5.3-py3-none-any.whl size=14812 sha256=3c34465cf828c65b754e66299c91958e80a8444a5bf1abf81f3a4827f7823af2
#   Stored in directory: c:\users\tushar\appdata\local\pip\cache\wheels\6c\c8\cc\9e2890bb9ec2a93fe499970976a92413b4ac91417e5912ba50
# Successfully built gbif restkit http-parser socketpool
# Installing collected packages: socketpool, http-parser, restkit, gbif
# Successfully installed gbif-0.1.0 http-parser-0.9.0 restkit-4.2.2 socketpool-0.5.3

# %%
#When using GBIF built-in API, use for downloading
#Start of search query
command = 'curl -i --user tusharlaksh:Cheeselord03! -H "Content-Type: application/json" -H "Accept: application/json" -X '

# %%
#Good for lookup/research
from pygbif import species, occurrences, registry, maps

# %%
species.name_backbone(name='Elasmobranchii')
# Out:
# {'usageKey': 121,
#  'scientificName': 'Elasmobranchii',
#  'canonicalName': 'Elasmobranchii',
#  'rank': 'CLASS',
#  'status': 'ACCEPTED',
#  'confidence': 94,
#  'matchType': 'EXACT',
#  'kingdom': 'Animalia',
#  'phylum': 'Chordata',
#  'kingdomKey': 1,
#  'phylumKey': 44,
#  'classKey': 121,
#  'synonym': False,
#  'class': 'Elasmobranchii'}

# %%
registry.dataset_suggest(q='Elasmobranchii')
# Out:
# [{'key': '2a47dd25-4813-4d3c-99c1-1bc1aeb774e7',
#   'title': 'FBIP: Actinopterygii and Elasmobranchii occurrence record throughout South Africa',
#   'description': 'Records of marine fish samples throughout South Africa (Modern_occurance _records_AttwoodDatabase2_UCT)',
#   'type': 'OCCURRENCE'},
#  {'key': '945c11aa-91c3-427c-944e-3362b7031ef5',
#   'title': 'Sharks of the Persian (Arabian) Gulf: a first annotated checklist (Chondrichthyes: Elasmobranchii)',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Moore, Alec B. M., Ward, Robert D., Peirce, Richard (2012): Sharks of the Persian (Arabian) Gulf: a first annotated checklist (Chondrichthyes: Elasmobranchii). Zootaxa 3167: 1-16, DOI: 10.5281/zenodo.279779',
#   'type': 'CHECKLIST'},
#  {'key': 'd53ee09e-8458-4130-a337-6071e3a81726',
#   'title': 'Lista patrón de los tiburones, rayas y quimeras (Chondrichthyes, Elasmobranchii, Holocephali) de México',
#   'description': 'An annotated checklist of the species of sharks, rays and chimaeras (chondrichthyan fishes) occurring in Mexican waters is presented, based on a thorough review of the literature and electronic database searches, examination of museum collection specimens, and unpublished records obtained during fieldwork conducted in the last four years. The checklist contains information of at least 214 species of chondrichthyan fishes that ocur in Mexican marine and brackish waters, assigned to 84 genera, 40 families and 14 orders. It includes eight species of chimaeras, 95 of batoids and 111 of sharks. \nMexican´s chondrichthyan fauna is one of the richest in the world, with almost 17.3% of the known species. Additionally, 16 species are included, as their occurrence in Mexican marine waters is probable according with distributional patterns.',
#   'type': 'OCCURRENCE'},
#  {'key': '58d27495-1884-44e9-9f26-31248d549e95',
#   'title': 'First record of the marbled ray, Dasyatis marmorata (Elasmobranchii: Dasyatidae), from Greece (central Aegean Sea)',
#   'type': 'CHECKLIST'},
#  {'key': '10e7fd54-75a7-49da-8677-2aa61a91c413',
#   'title': 'Egg capsules of Atlantoraja cyclophora (Regan, 1903) and A. platana (Günther, 1880) (Pisces, Elasmobranchii, Rajidae).',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article M. C. Oddone, A. S. Marçal, C. M. Vooren (2004): Egg capsules of Atlantoraja cyclophora (Regan, 1903) and A. platana (Günther, 1880) (Pisces, Elasmobranchii, Rajidae). Zootaxa 426: 1-4, URL: http://www.zoobank.org/urn:lsid:zoobank.org:pub:3584B121-C5A0-461D-B121-3EB205A23515',
#   'type': 'CHECKLIST'},
#  {'key': '2423589d-ce8f-4425-9a73-c62ad530bfd8',
#   'title': 'Complementary redescription of Raja lintea Fries, 1839 (Elasmobranchii, Rajidae) and its revised generic assignment',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Stehmann, Matthias F. W. (2012): Complementary redescription of Raja lintea Fries, 1839 (Elasmobranchii, Rajidae) and its revised generic assignment. Zootaxa 3331: 44-68, DOI: 10.5281/zenodo.281245',
#   'type': 'CHECKLIST'},
#  {'key': '485e61f0-1275-4b5f-9d88-0a11d60e02e6',
#   'title': 'Emerging global novelty in phyllobothriidean tapeworms (Cestoda: Phyllobothriidea) from sharks and skates (Elasmobranchii)',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Caira, Janine N., Bueno, Veronica, Jensen, Kirsten (2021): Emerging global novelty in phyllobothriidean tapeworms (Cestoda: Phyllobothriidea) from sharks and skates (Elasmobranchii). Zoological Journal of the Linnean Society 193: 1336-1363, DOI: 10.1093/zoolinnean/zlaa185, URL: https://doi.org/10.1093/zoolinnean/zlaa185',
#   'type': 'CHECKLIST'},
#  {'key': 'd862f638-9650-4510-9318-cbab38b1439e',
#   'title': 'Pastinachus solocirostris sp. nov., a new species of Stingray (Elasmobranchii: Myliobatiformes) from the Indo-Malay Archipelago.',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Peter R. Last, B. Mabel Manjaji, Gordon K. Yearsley (2005): Pastinachus solocirostris sp. nov., a new species of Stingray (Elasmobranchii: Myliobatiformes) from the Indo-Malay Archipelago. Zootaxa 1040: 1-16, URL: http://www.zoobank.org/urn:lsid:zoobank.org:pub:756A36A1-95BC-4FD9-A58A-1DA0EAB3A830',
#   'type': 'CHECKLIST'},
#  {'key': '01a6e5c3-a256-4838-9f89-173995eda768',
#   'title': 'Zanobatus maculatus, a new species of panray from the Gulf of Guinea, eastern central Atlantic (Elasmobranchii: Batoidea: Zanobatidae)',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Séret, Bernard (2016): Zanobatus maculatus, a new species of panray from the Gulf of Guinea, eastern central Atlantic (Elasmobranchii: Batoidea: Zanobatidae). Zootaxa 4161 (4): 509-522, DOI: http://doi.org/10.11646/zootaxa.4161.4.2',
#   'type': 'CHECKLIST'},
#  {'key': '4e569461-b42c-44e3-a46c-64d360a29257',
#   'title': 'Pastinachus solocirostris sp. nov., a new species of Stingray (Elasmobranchii: Myliobatiformes) from the Indo – Malay Archipelago',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Last, Peter R., Manjaji, B. Mabel, Yearsley, Gordon K. (2005): Pastinachus solocirostris sp. nov., a new species of Stingray (Elasmobranchii: Myliobatiformes) from the Indo – Malay Archipelago. Zootaxa 1040: 1-16, DOI: 10.5281/zenodo.169811',
#   'type': 'CHECKLIST'},
#  {'key': '852737fe-2816-4ca8-a8f9-9f67b9a46f33',
#   'title': 'Rhynchorhina mauritaniensis, a new genus and species of wedgefish from the eastern central Atlantic (Elasmobranchii: Batoidea: Rhinidae)',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Séret, Bernard, Naylor, Gavin J. P. (2016): Rhynchorhina mauritaniensis, a new genus and species of wedgefish from the eastern central Atlantic (Elasmobranchii: Batoidea: Rhinidae). Zootaxa 4138 (2): 291-308, DOI: http://doi.org/10.11646/zootaxa.4138.2.4',
#   'type': 'CHECKLIST'},
#  {'key': '78065eb6-8757-4d91-aa23-a7bc65ef0598',
#   'title': 'Rajella paucispinosa n. sp., a new deep-water skate (Elasmobranchii, Rajidae) from the western Indian Ocean off South Mozambique, and a revised generic diagnosis',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Weigmann, Simon, Stehmann, Matthias F. W., Thiel, Ralf (2014): Rajella paucispinosa n. sp., a new deep-water skate (Elasmobranchii, Rajidae) from the western Indian Ocean off South Mozambique, and a revised generic diagnosis. Zootaxa 3847 (3): 359-387, DOI: http://dx.doi.org/10.11646/zootaxa.3847.3.3',
#   'type': 'CHECKLIST'},
#  {'key': '22339a0f-face-4296-a851-b006076e350a',
#   'title': 'Complementary redescription of Anacanthobatis ori (Wallace, 1967) and its assignment to Indobatis n. g. (Elasmobranchii, Anacanthobatidae), with comments on other legskates',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Weigmann, Simon, Stehmann, Matthias F. W., Thiel, Ralf (2014): Complementary redescription of Anacanthobatis ori (Wallace, 1967) and its assignment to Indobatis n. g. (Elasmobranchii, Anacanthobatidae), with comments on other legskates. Zootaxa 3779 (2): 101-132, DOI: http://dx.doi.org/10.11646/zootaxa.3779.2.1',
#   'type': 'CHECKLIST'},
#  {'key': 'fcd2980a-fc70-4170-a912-89a1a47e63c7',
#   'title': 'Stoibocephalum n. gen. (Cestoda: Lecanicephalidea) from the sharkray, Rhina ancylostoma Bloch & Schneider (Elasmobranchii: Rhinopristiformes), from northern Australia',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Cielocha, Joanna J., Jensen, Kirsten (2013): Stoibocephalum n. gen. (Cestoda: Lecanicephalidea) from the sharkray, Rhina ancylostoma Bloch &amp; Schneider (Elasmobranchii: Rhinopristiformes), from northern Australia. Zootaxa 3626 (4): 558-568, DOI: http://dx.doi.org/10.11646/zootaxa.3626.4.9',
#   'type': 'CHECKLIST'},
#  {'key': '1350f53e-7270-41d5-85de-e9ba8b232c23',
#   'title': 'Five new species of Acanthobothrium (Cestoda: Onchoproteocephalidea) from the long-tailed butterfly ray, Gymnura cf. poecilura (Elasmobranchii: Gymnuridae) from the Persian Gulf and Gulf of Oman',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Maleki, Loghman, Malek, Masoumeh, Palm, Harry W. (2019): Five new species of Acanthobothrium (Cestoda: Onchoproteocephalidea) from the long-tailed butterfly ray, Gymnura cf. poecilura (Elasmobranchii: Gymnuridae) from the Persian Gulf and Gulf of Oman. Zootaxa 4609 (2): 289-307, DOI: https://doi.org/10.11646/zootaxa.4609.2.5',
#   'type': 'CHECKLIST'},
#  {'key': '5b11e03c-6b52-4799-9a8b-d04680c2762b',
#   'title': 'Dendromonocotyle bradsmithi n. sp. (Monogenea: Monocotylidae) from the skin of Myliobatis australis (Elasmobranchii: Myliobatidae) off Adelaide and Perth, Australia: description of adult and larva',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Chisholm, Leslie A., Glennon, Vanessa, Whittington, Ian D. (2005): Dendromonocotyle bradsmithi n. sp. (Monogenea: Monocotylidae) from the skin of Myliobatis australis (Elasmobranchii: Myliobatidae) off Adelaide and Perth, Australia: description of adult and larva. Zootaxa 951: 1-15, DOI: 10.5281/zenodo.171185',
#   'type': 'CHECKLIST'},
#  {'key': '35c9232b-6917-43f7-a169-bc4faacb4f47',
#   'title': 'Insights on the identities of sharks of the Rhizoprionodon acutus (Elasmobranchii: Carcharhiniformes) species complex based on three new species of Phoreiobothrium (Cestoda: Onchoproteocephalidea)',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Caira, J. N., Jensen, K. (2015): Insights on the identities of sharks of the Rhizoprionodon acutus (Elasmobranchii: Carcharhiniformes) species complex based on three new species of Phoreiobothrium (Cestoda: Onchoproteocephalidea). Zootaxa 4059 (2): 335-350, DOI: http://dx.doi.org/10.11646/zootaxa.4059.2.5',
#   'type': 'CHECKLIST'},
#  {'key': '7d9c2573-2d06-4a60-aead-85cc2fce2a85',
#   'title': 'Redescription of Prosaetes rhinodontis (Wright, 1876) (Crustacea: Copepoda: Siphonostomatoida), an enigmatic parasite of the whale shark, Rhincodon typus Smith (Elasmobranchii: Orectolobiformes: Rhincodontidae)',
#   'description': 'This dataset contains the digitized treatments in Plazi based on the original journal article Tang, Danny, Yanagisawa, Makio, Nagasawa, Kazuya (2010): Redescription of Prosaetes rhinodontis (Wright, 1876) (Crustacea: Copepoda: Siphonostomatoida), an enigmatic parasite of the whale shark, Rhincodon typus Smith (Elasmobranchii: Orectolobiformes: Rhincodontidae). Zootaxa 2493: 1-15, DOI: 10.5281/zenodo.195669',
#   'type': 'CHECKLIST'}]

# %%
key = species.name_backbone(name='Elasmobranchii')['usageKey']

# %%
occurrences.search(taxonKey = key)
# Out:
# {'offset': 0,
#  'limit': 300,
#  'endOfRecords': False,
#  'count': 2815726,
#  'results': [{'key': 4011891093,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:20:02.238+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Claire Goiran',
#       'http://purl.org/dc/terms/rightsHolder': 'Claire Goiran',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250027992/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250027992',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T08:55:52-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250027992',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'},
#      {'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Claire Goiran',
#       'http://purl.org/dc/terms/rightsHolder': 'Claire Goiran',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250028003/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250028003',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T08:56:26-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250028003',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'sex': 'MALE',
#    'lifeStage': 'Adult',
#    'taxonKey': 9677005,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 8214029,
#    'familyKey': 2195,
#    'genusKey': 2419591,
#    'speciesKey': 2419592,
#    'acceptedTaxonKey': 2419592,
#    'scientificName': 'Neotrygon trigonoides (Castelnau, 1873)',
#    'acceptedScientificName': 'Neotrygon kuhlii (Müller & Henle, 1841)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Myliobatiformes',
#    'family': 'Dasyatidae',
#    'genus': 'Neotrygon',
#    'species': 'Neotrygon kuhlii',
#    'genericName': 'Neotrygon',
#    'specificEpithet': 'trigonoides',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'SYNONYM',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-01T02:28:19',
#    'decimalLongitude': 166.438863,
#    'decimalLatitude': -22.303971,
#    'coordinateUncertaintyInMeters': 91.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'Sud',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T08:55:00',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-10T07:55:49.000+00:00',
#    'lastInterpreted': '2023-04-19T13:20:02.238+00:00',
#    'references': 'https://www.inaturalist.org/observations/145548814',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145548814'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250027992',
#      'created': '2023-01-01T16:55:52.000+00:00',
#      'creator': 'Claire Goiran',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Claire Goiran',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250027992/original.jpeg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250028003',
#      'created': '2023-01-01T16:56:26.000+00:00',
#      'creator': 'Claire Goiran',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Claire Goiran',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250028003/original.jpeg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Claire Goiran',
#    'identifiedBy': 'Claire Goiran',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'NC',
#    'recordedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-1649-4418'}],
#    'identifiedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-1649-4418'}],
#    'country': 'New Caledonia',
#    'rightsHolder': 'Claire Goiran',
#    'identifier': '145548814',
#    'http://unknown.org/nick': 'clairegoiran',
#    'verbatimEventDate': '2023/01/01 08:55',
#    'collectionCode': 'Observations',
#    'gbifID': '4011891093',
#    'verbatimLocality': 'Province Sud, Nouvelle-Calédonie',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145548814',
#    'taxonID': '500873',
#    'catalogNumber': '145548814',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '08:55:00+11:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324064721'},
#   {'key': 4011506133,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:20:48.976+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Claire Goiran',
#       'http://purl.org/dc/terms/rightsHolder': 'Claire Goiran',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250028074/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250028074',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T09:10:06-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250028074',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'},
#      {'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Claire Goiran',
#       'http://purl.org/dc/terms/rightsHolder': 'Claire Goiran',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250028114/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250028114',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T09:10:42-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250028114',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'sex': 'FEMALE',
#    'taxonKey': 9677005,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 8214029,
#    'familyKey': 2195,
#    'genusKey': 2419591,
#    'speciesKey': 2419592,
#    'acceptedTaxonKey': 2419592,
#    'scientificName': 'Neotrygon trigonoides (Castelnau, 1873)',
#    'acceptedScientificName': 'Neotrygon kuhlii (Müller & Henle, 1841)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Myliobatiformes',
#    'family': 'Dasyatidae',
#    'genus': 'Neotrygon',
#    'species': 'Neotrygon kuhlii',
#    'genericName': 'Neotrygon',
#    'specificEpithet': 'trigonoides',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'SYNONYM',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-01T02:28:22',
#    'decimalLongitude': 166.438863,
#    'decimalLatitude': -22.303971,
#    'coordinateUncertaintyInMeters': 91.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'Sud',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T09:10:00',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-10T07:55:30.000+00:00',
#    'lastInterpreted': '2023-04-19T13:20:48.976+00:00',
#    'references': 'https://www.inaturalist.org/observations/145548825',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145548825'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250028074',
#      'created': '2023-01-01T17:10:06.000+00:00',
#      'creator': 'Claire Goiran',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Claire Goiran',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250028074/original.jpeg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250028114',
#      'created': '2023-01-01T17:10:42.000+00:00',
#      'creator': 'Claire Goiran',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Claire Goiran',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250028114/original.jpeg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Claire Goiran',
#    'identifiedBy': 'Claire Goiran',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'NC',
#    'recordedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-1649-4418'}],
#    'identifiedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-1649-4418'}],
#    'country': 'New Caledonia',
#    'rightsHolder': 'Claire Goiran',
#    'identifier': '145548825',
#    'http://unknown.org/nick': 'clairegoiran',
#    'verbatimEventDate': '2023/01/01 09:10',
#    'collectionCode': 'Observations',
#    'gbifID': '4011506133',
#    'verbatimLocality': 'Province Sud, Nouvelle-Calédonie',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145548825',
#    'taxonID': '500873',
#    'catalogNumber': '145548825',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '09:10:00+11:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324064738'},
#   {'key': 4011556136,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'AU',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:28:03.864+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Melissa Staines',
#       'http://purl.org/dc/terms/rightsHolder': 'Melissa Staines',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250033054/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250033054',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T10:31:36-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250033054',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'},
#      {'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Melissa Staines',
#       'http://purl.org/dc/terms/rightsHolder': 'Melissa Staines',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250033064/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250033064',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T10:31:30-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250033064',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Adult',
#    'taxonKey': 2417559,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 769,
#    'familyKey': 2200,
#    'genusKey': 2417540,
#    'speciesKey': 2417559,
#    'acceptedTaxonKey': 2417559,
#    'scientificName': 'Orectolobus ornatus (De Vis, 1883)',
#    'acceptedScientificName': 'Orectolobus ornatus (De Vis, 1883)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Orectolobiformes',
#    'family': 'Orectolobidae',
#    'genus': 'Orectolobus',
#    'species': 'Orectolobus ornatus',
#    'genericName': 'Orectolobus',
#    'specificEpithet': 'ornatus',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-01T03:02:41',
#    'decimalLongitude': 153.341481,
#    'decimalLatitude': -29.609887,
#    'coordinateUncertaintyInMeters': 113.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'New South Wales',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T10:31:36',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-10T07:54:13.000+00:00',
#    'lastInterpreted': '2023-04-19T13:28:03.864+00:00',
#    'references': 'https://www.inaturalist.org/observations/145550321',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145550321'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250033064',
#      'created': '2023-01-01T18:31:30.000+00:00',
#      'creator': 'Melissa Staines',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Melissa Staines',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250033064/original.jpeg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250033054',
#      'created': '2023-01-01T18:31:36.000+00:00',
#      'creator': 'Melissa Staines',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Melissa Staines',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250033054/original.jpeg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {'level0': {'gid': 'AUS', 'name': 'Australia'},
#     'level1': {'gid': 'AUS.5_1', 'name': 'New South Wales'},
#     'level2': {'gid': 'AUS.5.33_1', 'name': 'Clarence Valley'}},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Melissa Staines',
#    'identifiedBy': 'Melissa Staines',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'AU',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'Australia',
#    'rightsHolder': 'Melissa Staines',
#    'identifier': '145550321',
#    'http://unknown.org/nick': 'melissa_staines',
#    'verbatimEventDate': '2023-01-01 10:31:36',
#    'collectionCode': 'Observations',
#    'gbifID': '4011556136',
#    'verbatimLocality': 'On the beachfront, Brooms Head NSW 2463, Australia',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145550321',
#    'taxonID': '63635',
#    'catalogNumber': '145550321',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '10:31:36+11:00',
#    'occurrenceRemarks': 'Approx 70cm long. In a rockpool',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324069960'},
#   {'key': 4011711161,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'AU',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:24:49.450+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Warwick Moyse',
#       'http://purl.org/dc/terms/rightsHolder': 'Warwick Moyse',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250059169/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250059169',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T11:07:35-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250059169',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5215675,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 886,
#    'familyKey': 5890,
#    'genusKey': 2418859,
#    'speciesKey': 5215675,
#    'acceptedTaxonKey': 5215675,
#    'scientificName': 'Heterodontus portusjacksoni (Meyer, 1793)',
#    'acceptedScientificName': 'Heterodontus portusjacksoni (Meyer, 1793)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Heterodontiformes',
#    'family': 'Heterodontidae',
#    'genus': 'Heterodontus',
#    'species': 'Heterodontus portusjacksoni',
#    'genericName': 'Heterodontus',
#    'specificEpithet': 'portusjacksoni',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-01T08:48:33',
#    'decimalLongitude': 138.594799,
#    'decimalLatitude': -35.341946,
#    'coordinateUncertaintyInMeters': 28706.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'South Australia',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T11:07:00',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-10T07:25:00.000+00:00',
#    'lastInterpreted': '2023-04-19T13:24:49.450+00:00',
#    'references': 'https://www.inaturalist.org/observations/145564092',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145564092'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250059169',
#      'created': '2023-01-01T19:07:35.000+00:00',
#      'creator': 'Warwick Moyse',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Warwick Moyse',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250059169/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {'level0': {'gid': 'AUS', 'name': 'Australia'},
#     'level1': {'gid': 'AUS.8_1', 'name': 'South Australia'},
#     'level2': {'gid': 'AUS.8.3_1', 'name': 'Alexandrina'}},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Warwick Moyse',
#    'identifiedBy': 'Warwick Moyse',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'AU',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'Australia',
#    'rightsHolder': 'Warwick Moyse',
#    'identifier': '145564092',
#    'http://unknown.org/nick': 'wamoz',
#    'informationWithheld': 'Coordinate uncertainty increased to 28706m at the request of the observer',
#    'verbatimEventDate': '2023/01/01 11:07 AM',
#    'collectionCode': 'Observations',
#    'gbifID': '4011711161',
#    'verbatimLocality': 'South Australia, AU',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145564092',
#    'taxonID': '57810',
#    'catalogNumber': '145564092',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '11:07:00+10:30',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324107065'},
#   {'key': 4028647261,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:21:33.156+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'fitzyegirl',
#       'http://purl.org/dc/terms/rightsHolder': 'fitzyegirl',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250103275/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250103275',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T16:54:32Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250103275',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Egg',
#    'taxonKey': 11005272,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 884,
#    'familyKey': 5877,
#    'genusKey': 2342057,
#    'speciesKey': 5216061,
#    'acceptedTaxonKey': 5216061,
#    'scientificName': 'Rostroraja eglanteria (Bosc, 1800)',
#    'acceptedScientificName': 'Raja eglanteria Bosc, 1800',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rajiformes',
#    'family': 'Rajidae',
#    'genus': 'Raja',
#    'species': 'Raja eglanteria',
#    'genericName': 'Rostroraja',
#    'specificEpithet': 'eglanteria',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'SYNONYM',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-10T07:21:05',
#    'decimalLongitude': -75.077859,
#    'decimalLatitude': 38.731558,
#    'coordinateUncertaintyInMeters': 9.0,
#    'continent': 'NORTH_AMERICA',
#    'stateProvince': 'Delaware',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T11:54:32',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-26T18:55:30.000+00:00',
#    'lastInterpreted': '2023-04-19T13:21:33.156+00:00',
#    'references': 'https://www.inaturalist.org/observations/145588001',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145588001'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250103275',
#      'created': '2023-01-01T16:54:32.000+00:00',
#      'creator': 'fitzyegirl',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'fitzyegirl',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250103275/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'fitzyegirl',
#    'identifiedBy': 'Clinton Duffy',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'US',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'United States of America',
#    'rightsHolder': 'fitzyegirl',
#    'identifier': '145588001',
#    'http://unknown.org/nick': 'fitzyegirl',
#    'verbatimEventDate': '2023-01-01 11:54:32-05:00',
#    'collectionCode': 'Observations',
#    'gbifID': '4028647261',
#    'verbatimLocality': 'Ocean Dr, Henlopen Acres, DE, US',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145588001',
#    'taxonID': '1032432',
#    'catalogNumber': '145588001',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '11:54:32-05:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '326211327'},
#   {'key': 4014877766,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:24:53.252+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Campbell Scott',
#       'http://purl.org/dc/terms/rightsHolder': 'Campbell Scott',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250105548/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250105548',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T17:07:33Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250105548',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'},
#      {'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Campbell Scott',
#       'http://purl.org/dc/terms/rightsHolder': 'Campbell Scott',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250105568/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250105568',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T17:07:33Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250105568',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Egg',
#    'taxonKey': 2418609,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 887,
#    'familyKey': 2208,
#    'genusKey': 2418605,
#    'speciesKey': 2418609,
#    'acceptedTaxonKey': 2418609,
#    'scientificName': 'Haploblepharus edwardsii (Schinz, 1822)',
#    'acceptedScientificName': 'Haploblepharus edwardsii (Schinz, 1822)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Carcharhiniformes',
#    'family': 'Scyliorhinidae',
#    'genus': 'Haploblepharus',
#    'species': 'Haploblepharus edwardsii',
#    'genericName': 'Haploblepharus',
#    'specificEpithet': 'edwardsii',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'EN',
#    'dateIdentified': '2023-01-08T22:06:59',
#    'decimalLongitude': 23.309676,
#    'decimalLatitude': -34.098578,
#    'coordinateUncertaintyInMeters': 28874.0,
#    'continent': 'AFRICA',
#    'stateProvince': 'Western Cape',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T19:07:33',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-09T11:19:33.000+00:00',
#    'lastInterpreted': '2023-04-19T13:24:53.252+00:00',
#    'references': 'https://www.inaturalist.org/observations/145589134',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145589134'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250105568',
#      'created': '2023-01-01T17:07:33.000+00:00',
#      'creator': 'Campbell Scott',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Campbell Scott',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250105568/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250105548',
#      'created': '2023-01-01T17:07:33.000+00:00',
#      'creator': 'Campbell Scott',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Campbell Scott',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250105548/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {'level0': {'gid': 'ZAF', 'name': 'South Africa'},
#     'level1': {'gid': 'ZAF.9_1', 'name': 'Western Cape'},
#     'level2': {'gid': 'ZAF.9.4_1', 'name': 'Eden'},
#     'level3': {'gid': 'ZAF.9.4.1_1', 'name': 'Bitou'}},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Campbell Scott',
#    'identifiedBy': 'Clinton Duffy',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'ZA',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'South Africa',
#    'rightsHolder': 'Campbell Scott',
#    'identifier': '145589134',
#    'http://unknown.org/nick': 'nomfu',
#    'informationWithheld': 'Coordinate uncertainty increased to 28874m to protect threatened taxon',
#    'verbatimEventDate': '2023-01-01 19:07:33+02:00',
#    'collectionCode': 'Observations',
#    'gbifID': '4014877766',
#    'verbatimLocality': 'Eden, ZA-WC, ZA',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145589134',
#    'taxonID': '102101',
#    'catalogNumber': '145589134',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '19:07:33+02:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '325871049'},
#   {'key': 4014872762,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'GB',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:21:35.799+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'alsa143',
#       'http://purl.org/dc/terms/rightsHolder': 'alsa143',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250121707/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250121707',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T13:35:40Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250121707',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Egg',
#    'taxonKey': 5216024,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 884,
#    'familyKey': 5877,
#    'genusKey': 2342057,
#    'speciesKey': 5216024,
#    'acceptedTaxonKey': 5216024,
#    'scientificName': 'Raja clavata Linnaeus, 1758',
#    'acceptedScientificName': 'Raja clavata Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rajiformes',
#    'family': 'Rajidae',
#    'genus': 'Raja',
#    'species': 'Raja clavata',
#    'genericName': 'Raja',
#    'specificEpithet': 'clavata',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NT',
#    'dateIdentified': '2023-01-01T19:02:27',
#    'decimalLongitude': -3.566021,
#    'decimalLatitude': 51.052102,
#    'coordinateUncertaintyInMeters': 26261.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'England',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T13:35:40',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-10T07:18:39.000+00:00',
#    'lastInterpreted': '2023-04-19T13:21:35.799+00:00',
#    'references': 'https://www.inaturalist.org/observations/145597636',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145597636'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250121707',
#      'created': '2023-01-01T13:35:40.000+00:00',
#      'creator': 'alsa143',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'alsa143',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250121707/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {'level0': {'gid': 'GBR', 'name': 'United Kingdom'},
#     'level1': {'gid': 'GBR.1_1', 'name': 'England'},
#     'level2': {'gid': 'GBR.1.87_1', 'name': 'Somerset'},
#     'level3': {'gid': 'GBR.1.87.5_1', 'name': 'West Somerset'}},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'alsa143',
#    'identifiedBy': 'alsa143',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'GB',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'United Kingdom of Great Britain and Northern Ireland',
#    'rightsHolder': 'alsa143',
#    'identifier': '145597636',
#    'http://unknown.org/nick': 'alsa143',
#    'informationWithheld': 'Coordinate uncertainty increased to 26261m to protect threatened taxon',
#    'verbatimEventDate': '2023-01-01 13:35:40Z',
#    'collectionCode': 'Observations',
#    'gbifID': '4014872762',
#    'verbatimLocality': 'Somerset, England, GB',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145597636',
#    'taxonID': '48397',
#    'catalogNumber': '145597636',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '13:35:40+00:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324194718'},
#   {'key': 4011697165,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'GB',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:22:29.211+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'alsa143',
#       'http://purl.org/dc/terms/rightsHolder': 'alsa143',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250122407/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250122407',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T13:28:13Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250122407',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 2418684,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 887,
#    'familyKey': 2208,
#    'genusKey': 9171444,
#    'speciesKey': 2418684,
#    'acceptedTaxonKey': 2418684,
#    'scientificName': 'Scyliorhinus canicula (Linnaeus, 1758)',
#    'acceptedScientificName': 'Scyliorhinus canicula (Linnaeus, 1758)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Carcharhiniformes',
#    'family': 'Scyliorhinidae',
#    'genus': 'Scyliorhinus',
#    'species': 'Scyliorhinus canicula',
#    'genericName': 'Scyliorhinus',
#    'specificEpithet': 'canicula',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-01T19:07:51',
#    'decimalLongitude': -3.432183,
#    'decimalLatitude': 51.196197,
#    'coordinateUncertaintyInMeters': 12.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'England',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T13:28:13',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-02T06:16:38.000+00:00',
#    'lastInterpreted': '2023-04-19T13:22:29.211+00:00',
#    'references': 'https://www.inaturalist.org/observations/145597968',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145597968'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250122407',
#      'created': '2023-01-01T13:28:13.000+00:00',
#      'creator': 'alsa143',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'alsa143',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250122407/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {'level0': {'gid': 'GBR', 'name': 'United Kingdom'},
#     'level1': {'gid': 'GBR.1_1', 'name': 'England'},
#     'level2': {'gid': 'GBR.1.87_1', 'name': 'Somerset'},
#     'level3': {'gid': 'GBR.1.87.5_1', 'name': 'West Somerset'}},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'alsa143',
#    'identifiedBy': 'alsa143',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'GB',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'United Kingdom of Great Britain and Northern Ireland',
#    'rightsHolder': 'alsa143',
#    'identifier': '145597968',
#    'http://unknown.org/nick': 'alsa143',
#    'verbatimEventDate': '2023-01-01 13:28:13Z',
#    'collectionCode': 'Observations',
#    'gbifID': '4011697165',
#    'verbatimLocality': 'Blue Anchor Bay, Minehead, England, GB',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145597968',
#    'taxonID': '112372',
#    'catalogNumber': '145597968',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '13:28:13+00:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324195734'},
#   {'key': 4011714168,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'GB',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:19:06.341+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'alsa143',
#       'http://purl.org/dc/terms/rightsHolder': 'alsa143',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250122686/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250122686',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T12:38:51Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250122686',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 2418684,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 887,
#    'familyKey': 2208,
#    'genusKey': 9171444,
#    'speciesKey': 2418684,
#    'acceptedTaxonKey': 2418684,
#    'scientificName': 'Scyliorhinus canicula (Linnaeus, 1758)',
#    'acceptedScientificName': 'Scyliorhinus canicula (Linnaeus, 1758)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Carcharhiniformes',
#    'family': 'Scyliorhinidae',
#    'genus': 'Scyliorhinus',
#    'species': 'Scyliorhinus canicula',
#    'genericName': 'Scyliorhinus',
#    'specificEpithet': 'canicula',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-01T19:10:30',
#    'decimalLongitude': -3.432817,
#    'decimalLatitude': 51.197333,
#    'coordinateUncertaintyInMeters': 16.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'England',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T12:38:51',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-10T07:18:15.000+00:00',
#    'lastInterpreted': '2023-04-19T13:19:06.341+00:00',
#    'references': 'https://www.inaturalist.org/observations/145598108',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145598108'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250122686',
#      'created': '2023-01-01T12:38:51.000+00:00',
#      'creator': 'alsa143',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'alsa143',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250122686/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'alsa143',
#    'identifiedBy': 'alsa143',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'GB',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'United Kingdom of Great Britain and Northern Ireland',
#    'rightsHolder': 'alsa143',
#    'identifier': '145598108',
#    'http://unknown.org/nick': 'alsa143',
#    'verbatimEventDate': '2023-01-01 12:38:51Z',
#    'collectionCode': 'Observations',
#    'gbifID': '4011714168',
#    'verbatimLocality': 'Blue Anchor Bay, Minehead, England, GB',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145598108',
#    'taxonID': '112372',
#    'catalogNumber': '145598108',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '12:38:51+00:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324196169'},
#   {'key': 4015216724,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:21:21.762+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'active4',
#       'http://purl.org/dc/terms/rightsHolder': 'active4',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250131495/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250131495',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-01T20:07:59Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '250131495',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 2418800,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 887,
#    'familyKey': 2207,
#    'genusKey': 2418788,
#    'speciesKey': 2418800,
#    'acceptedTaxonKey': 2418800,
#    'scientificName': 'Sphyrna tiburo (Linnaeus, 1758)',
#    'acceptedScientificName': 'Sphyrna tiburo (Linnaeus, 1758)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Carcharhiniformes',
#    'family': 'Sphyrnidae',
#    'genus': 'Sphyrna',
#    'species': 'Sphyrna tiburo',
#    'genericName': 'Sphyrna',
#    'specificEpithet': 'tiburo',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'EN',
#    'dateIdentified': '2023-01-02T16:31:18',
#    'decimalLongitude': -82.820755,
#    'decimalLatitude': 28.047501,
#    'coordinateUncertaintyInMeters': 4.0,
#    'continent': 'NORTH_AMERICA',
#    'stateProvince': 'Florida',
#    'year': 2023,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2023-01-01T15:07:59',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-03-08T18:46:56.000+00:00',
#    'lastInterpreted': '2023-04-19T13:21:21.762+00:00',
#    'references': 'https://www.inaturalist.org/observations/145602547',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '145602547'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/250131495',
#      'created': '2023-01-01T20:07:59.000+00:00',
#      'creator': 'active4',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'active4',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250131495/original.jpeg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'active4',
#    'identifiedBy': 'yurimaoh',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'US',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'United States of America',
#    'rightsHolder': 'active4',
#    'identifier': '145602547',
#    'http://unknown.org/nick': 'active4',
#    'verbatimEventDate': 'Sun Jan 01 2023 15:07:59 GMT -0500 (EST)',
#    'collectionCode': 'Observations',
#    'gbifID': '4015216724',
#    'verbatimLocality': 'Dunedin',
#    'occurrenceID': 'https://www.inaturalist.org/observations/145602547',
#    'taxonID': '112960',
#    'catalogNumber': '145602547',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '15:07:59-05:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '324410334'},
#   {'key': 4014941783,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:23:49.159+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Tom Walker',
#       'http://purl.org/dc/terms/rightsHolder': 'Tom Walker',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/250135750/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/250135750',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
# ...
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Adult',
#    'taxonKey': 2419304,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 8214029,
#    'familyKey': 2193,
#    'genusKey': 10779164,
#    'speciesKey': 2419304,
#    'acceptedTaxonKey': 2419304,
#    'scientificName': 'Myliobatis tenuicaudatus Hector, 1877',
#    'acceptedScientificName': 'Myliobatis tenuicaudatus Hector, 1877',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Myliobatiformes',
#    'family': 'Myliobatidae',
#    'genus': 'Myliobatis',
#    'species': 'Myliobatis tenuicaudatus',
#    'genericName': 'Myliobatis',
#    'specificEpithet': 'tenuicaudatus',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-15T06:44:10',
#    'decimalLongitude': 151.500481,
#    'decimalLatitude': -33.364341,
#    'coordinateUncertaintyInMeters': 261.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'New South Wales',
#    'year': 2023,
#    'month': 1,
#    'day': 14,
#    'eventDate': '2023-01-14T16:20:16',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-19T09:34:17.000+00:00',
#    'lastInterpreted': '2023-04-19T13:17:15.319+00:00',
#    'references': 'https://www.inaturalist.org/observations/146583326',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '146583326'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/252044449',
#      'created': '2023-01-14T05:20:16.000+00:00',
#      'creator': 'dashtwostep',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'dashtwostep',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252044449/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/252044456',
#      'created': '2023-01-14T05:20:16.000+00:00',
#      'creator': 'dashtwostep',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'dashtwostep',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252044456/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'dashtwostep',
#    'identifiedBy': 'Clinton Duffy',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'AU',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'Australia',
#    'rightsHolder': 'dashtwostep',
#    'identifier': '146583326',
#    'http://unknown.org/nick': 'dashtwostep',
#    'verbatimEventDate': '2023-01-14 16:20:16+11:00',
#    'collectionCode': 'Observations',
#    'gbifID': '4018275241',
#    'verbatimLocality': 'South Pacific Ocean, Toowoon Bay, NSW, AU',
#    'occurrenceID': 'https://www.inaturalist.org/observations/146583326',
#    'taxonID': '106327',
#    'catalogNumber': '146583326',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '16:20:16+11:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '327300078'},
#   {'key': 4018162234,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:17:14.087+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'imogenisunderwater',
#       'http://purl.org/dc/terms/rightsHolder': 'imogenisunderwater',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252044443/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/252044443',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-14T01:37:00Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '252044443',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Adult',
#    'taxonKey': 2419488,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 8214029,
#    'familyKey': 2195,
#    'genusKey': 2419434,
#    'speciesKey': 2419488,
#    'acceptedTaxonKey': 2419488,
#    'scientificName': 'Bathytoshia brevicaudata (Hutton, 1875)',
#    'acceptedScientificName': 'Bathytoshia brevicaudata (Hutton, 1875)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Myliobatiformes',
#    'family': 'Dasyatidae',
#    'genus': 'Bathytoshia',
#    'species': 'Bathytoshia brevicaudata',
#    'genericName': 'Bathytoshia',
#    'specificEpithet': 'brevicaudata',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-15T03:46:37',
#    'decimalLongitude': 144.713709,
#    'decimalLatitude': -38.317805,
#    'coordinateUncertaintyInMeters': 15.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'Victoria',
#    'year': 2023,
#    'month': 1,
#    'day': 14,
#    'eventDate': '2023-01-14T12:37:00',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-15T08:59:27.000+00:00',
#    'lastInterpreted': '2023-04-19T13:17:14.087+00:00',
#    'references': 'https://www.inaturalist.org/observations/146583733',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '146583733'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/252044443',
#      'created': '2023-01-14T01:37:00.000+00:00',
#      'creator': 'imogenisunderwater',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'imogenisunderwater',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252044443/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'imogenisunderwater',
#    'identifiedBy': 'imogenisunderwater',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'AU',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'Australia',
#    'rightsHolder': 'imogenisunderwater',
#    'identifier': '146583733',
#    'http://unknown.org/nick': 'imogenisunderwater',
#    'verbatimEventDate': '2023/01/14 12:37 PM',
#    'collectionCode': 'Observations',
#    'gbifID': '4018162234',
#    'verbatimLocality': 'Portsea VIC 3944, Australia',
#    'occurrenceID': 'https://www.inaturalist.org/observations/146583733',
#    'taxonID': '623821',
#    'catalogNumber': '146583733',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '12:37:00+11:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '327272329'},
#   {'key': 4018551248,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'AU',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:17:47.621+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'jvanweenen',
#       'http://purl.org/dc/terms/rightsHolder': 'jvanweenen',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252048557/original.jpg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/252048557',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-15T03:09:38Z',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '252048557',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 7009918,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 9412443,
#    'familyKey': 5876,
#    'genusKey': 2419094,
#    'speciesKey': 7009918,
#    'acceptedTaxonKey': 7009918,
#    'scientificName': 'Trygonorrhina dumerilii (Castelnau, 1873)',
#    'acceptedScientificName': 'Trygonorrhina dumerilii (Castelnau, 1873)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rhinopristiformes',
#    'family': 'Rhinobatidae',
#    'genus': 'Trygonorrhina',
#    'species': 'Trygonorrhina dumerilii',
#    'genericName': 'Trygonorrhina',
#    'specificEpithet': 'dumerilii',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-15T04:04:00',
#    'decimalLongitude': 138.484572,
#    'decimalLatitude': -34.764542,
#    'coordinateUncertaintyInMeters': 5.0,
#    'continent': 'OCEANIA',
#    'stateProvince': 'South Australia',
#    'year': 2023,
#    'month': 1,
#    'day': 15,
#    'eventDate': '2023-01-15T13:39:38',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-02-14T05:28:35.000+00:00',
#    'lastInterpreted': '2023-04-19T13:17:47.621+00:00',
#    'references': 'https://www.inaturalist.org/observations/146584733',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '146584733'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/252048557',
#      'created': '2023-01-15T03:09:38.000+00:00',
#      'creator': 'jvanweenen',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'jvanweenen',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252048557/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'jvanweenen',
#    'identifiedBy': 'jvanweenen',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'AU',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'Australia',
#    'rightsHolder': 'jvanweenen',
#    'identifier': '146584733',
#    'http://unknown.org/nick': 'jvanweenen',
#    'verbatimEventDate': '2023-01-15 13:39:38+10:30',
#    'collectionCode': 'Observations',
#    'gbifID': '4018551248',
#    'verbatimLocality': 'Indian Ocean, Torrens Island, SA, AU',
#    'occurrenceID': 'https://www.inaturalist.org/observations/146584733',
#    'taxonID': '530756',
#    'catalogNumber': '146584733',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '13:39:38+10:30',
#    'occurrenceRemarks': 'Washed up on Bird Island.',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '327275077'},
#   {'key': 4018161201,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2023-04-18T14:51:01.646+00:00',
#    'lastParsed': '2023-04-19T13:19:58.039+00:00',
#    'crawlId': 358,
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/creator': 'Brodie Cass Talbott',
#       'http://purl.org/dc/terms/rightsHolder': 'Brodie Cass Talbott',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252063503/original.jpeg',
#       'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/252063503',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist',
#       'http://purl.org/dc/terms/created': '2023-01-14T16:07:59-08:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '252063503',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/format': 'image/jpeg'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Egg',
#    'taxonKey': 7913005,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 121,
#    'orderKey': 884,
#    'familyKey': 5877,
#    'genusKey': 7554168,
#    'speciesKey': 7913005,
#    'acceptedTaxonKey': 7913005,
#    'scientificName': 'Beringraja binoculata (Girard, 1855)',
#    'acceptedScientificName': 'Beringraja binoculata (Girard, 1855)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rajiformes',
#    'family': 'Rajidae',
#    'genus': 'Beringraja',
#    'species': 'Beringraja binoculata',
#    'genericName': 'Beringraja',
#    'specificEpithet': 'binoculata',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2023-01-15T07:30:07',
#    'decimalLongitude': -123.876495,
#    'decimalLatitude': 45.759597,
#    'coordinateUncertaintyInMeters': 27126.0,
#    'continent': 'NORTH_AMERICA',
#    'stateProvince': 'Oregon',
#    'year': 2023,
#    'month': 1,
#    'day': 14,
#    'eventDate': '2023-01-14T16:07:59',
#    'issues': ['COORDINATE_ROUNDED', 'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2023-01-15T11:07:05.000+00:00',
#    'lastInterpreted': '2023-04-19T13:19:58.039+00:00',
#    'references': 'https://www.inaturalist.org/observations/146592760',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'identifiers': [{'identifier': '146592760'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/252063503',
#      'created': '2023-01-15T00:07:59.000+00:00',
#      'creator': 'Brodie Cass Talbott',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Brodie Cass Talbott',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/252063503/original.jpeg'}],
#    'facts': [],
#    'relations': [],
#    'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#     'level1': {'gid': 'USA.38_1', 'name': 'Oregon'},
#     'level2': {'gid': 'USA.38.29_1', 'name': 'Tillamook'}},
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Brodie Cass Talbott',
#    'identifiedBy': 'Brodie Cass Talbott',
#    'geodeticDatum': 'WGS84',
#    'class': 'Elasmobranchii',
#    'countryCode': 'US',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'country': 'United States of America',
#    'rightsHolder': 'Brodie Cass Talbott',
#    'identifier': '146592760',
#    'http://unknown.org/nick': 'brodiecasstalbott',
#    'informationWithheld': 'Coordinate uncertainty increased to 27126m to protect threatened taxon',
#    'verbatimEventDate': '2023-01-14 16:07:59',
#    'collectionCode': 'Observations',
#    'gbifID': '4018161201',
#    'verbatimLocality': 'Oregon, US',
#    'occurrenceID': 'https://www.inaturalist.org/observations/146592760',
#    'taxonID': '607477',
#    'catalogNumber': '146592760',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '16:07:59-08:00',
#    'http://unknown.org/captive': 'wild',
#    'identificationID': '327305089'}],
#  'facets': []}

# %%
registry.dataset_suggest(type="OCCURRENCE", q='Elasmobranchii')
# Out:
# [{'key': '2a47dd25-4813-4d3c-99c1-1bc1aeb774e7',
#   'title': 'FBIP: Actinopterygii and Elasmobranchii occurrence record throughout South Africa',
#   'description': 'Records of marine fish samples throughout South Africa (Modern_occurance _records_AttwoodDatabase2_UCT)',
#   'type': 'OCCURRENCE'},
#  {'key': 'd53ee09e-8458-4130-a337-6071e3a81726',
#   'title': 'Lista patrón de los tiburones, rayas y quimeras (Chondrichthyes, Elasmobranchii, Holocephali) de México',
#   'description': 'An annotated checklist of the species of sharks, rays and chimaeras (chondrichthyan fishes) occurring in Mexican waters is presented, based on a thorough review of the literature and electronic database searches, examination of museum collection specimens, and unpublished records obtained during fieldwork conducted in the last four years. The checklist contains information of at least 214 species of chondrichthyan fishes that ocur in Mexican marine and brackish waters, assigned to 84 genera, 40 families and 14 orders. It includes eight species of chimaeras, 95 of batoids and 111 of sharks. \nMexican´s chondrichthyan fauna is one of the richest in the world, with almost 17.3% of the known species. Additionally, 16 species are included, as their occurrence in Mexican marine waters is probable according with distributional patterns.',
#   'type': 'OCCURRENCE'},
#  {'key': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'title': 'EOD – eBird Observation Dataset',
#   'description': 'eBird is a collective enterprise that takes a novel approach to citizen science by developing cooperative partnerships among experts in a wide range of fields: population ecologists, conservation biologists, quantitative ecologists, statisticians, computer scientists, GIS and informatics specialists, application developers, and data administrators. Managed by the Cornell Lab of Ornithology eBird’s goal is to increase data quantity through participant recruitment and engagement globally, but also to quantify and control for data quality issues such as observer variability, imperfect detection of species, and both spatial and temporal bias in data collection. eBird data are openly available and used by a broad spectrum of students, teachers, scientists, NGOs, government agencies, land managers, and policy makers. The result is that eBird has become a major source of biodiversity data, increasing our knowledge of the dynamics of species distributions, and having a direct impact on the conservation of birds and their habitats.',
#   'type': 'OCCURRENCE'},
#  {'key': '75956ee6-1a2b-4fa3-b3e8-ccda64ce6c2d',
#   'title': 'INPN - Données flore des CBN agrégées par la FCBN',
#   'description': 'Dès la création de leur Fédération (FCBN - www.fcbn.fr) en 1999, les onze Conservatoires botaniques nationaux (CBN) ont exprimé la volonté collective de constituer un système d’information national pour mettre en commun leurs données, et celles de leurs partenaires, sur la flore, la fonge et les végétations-habitats. C’est réellement en 2010 avec le lancement de l’établissement du Format Standard de Données sur la flore (FSD Flore), conçu comme le « format commun de données de la Fédération des CBN », que la démarche a été initiée. Il s’en est suivi de nombreux échanges ayant permis de finaliser le format, de le tester sur les premiers jeux de données, d’établir une charte d’adhésion au projet et d’élaborer le cadrage final de l’exercice d’agrégation des données. Le projet s’est concrétisé au premier trimestre 2013 à travers la mise au format des données détenues par les CBN et leur intégration dans le Système d’Information de la FCBN (SI-Flore). A l’horizon de l’année 2014, il résulte, de ce projet structurant, que la FCBN dispose d’un système d’information d’envergure nationale et fort de plus de 20 millions de données d’observation sur la flore de France. Les données centralisées ont été consolidées sur la base du référentiel TAXREF 5.0 et une mise à jour est prévue pour fin 2015.',
#   'type': 'OCCURRENCE'},
#  {'key': '721a99a4-71f4-4466-b346-83c367889238',
#   'title': 'USGS PWRC - Bird Banding Lab - US State Centroid - 1960-2010',
#   'description': 'The Bird Banding Laboratory (BBL) was established in 1920 to coordinate bird banding activities occurring in the United States and its Territories, a consequence of the Migratory Bird Treaty Act between the United States and Great Britain that was ratified in 1918. Originally a program within the US Biological Survey, it was also associated with the US Fish and Wildlife Service and National Biological Service before being transferred to the USGS in 1996. Among its many responsibilities, the BBL maintains the bird banding data collected in the United States and its Territories and every report of birds banded in the US that are encountered anywhere in the world. Computerization of the banding records was initiated in 1960 and the BBL annually processes approximately one million new banding records from the US. Banding data are essential for managing harvested migratory bird populations across North America. These data also provide a historical source of information on the status and distribution of birds in the United States and have greatly expanded our knowledge of bird migration patterns across this hemisphere. USGS Patuxent Wildlife Research Center (PWRC). This dataset is a checklist of birds that occur in each state.',
#   'type': 'OCCURRENCE'},
#  {'key': 'e7cbb0ed-04c6-44ce-ac86-ebe49f4efb28',
#   'title': 'Waarnemingen.be - Bird occurrences in Flanders and the Brussels Capital Region, Belgium',
#   'description': '<p>Waarnemingen.be - Bird occurrences in Flanders and the Brussels Capital Region, Belgium is a species occurrence dataset published by Natuurpunt. The dataset contains over 12.8 million bird (Aves) occurrences of 445 naturally occurring species (native, vagrant or migrant species), recorded by volunteers (citizen scientists), mainly since 2008. The occurrences are derived from the database http://www.waarnemingen.be, hosted at the nature conservation NGO Natuurpunt in collaboration with Stichting Natuurinformatie. Standardized information regarding sex, lifeStage, behavior, occurrenceRemarks, and samplingProtocol are included as well.</p>\n<p>Generalized and/or withheld information: location information is generalized to 5 x 5 km² Universal Transverse Mercator (UTM) grid cells. Observer name, exact XY-coordinates, toponyms, and photographs are not included in the published dataset, but are known in the source database.</p>\n<p>To allow anyone to use this dataset, we have released the data to the public domain under a Creative Commons Zero waiver (http://creativecommons.org/publicdomain/zero/1.0/). We would appreciate however, if you read and follow these norms for data use (http://www.natuurpunt.be/normen-voor-datagebruik) and provide a link to the original dataset (https://doi.org/10.15468/0mbhvd) whenever possible. If you use these data for a scientific paper, please cite the dataset following the applicable citation norms and/or consider us for co-authorship. We are always interested to provide more information or know how you have used the data, so please contact us via the contact information provided in the metadata or natuurdata&#64;natuurpunt.be.</p>\n<p>The publication of this dataset is supported by INBO and funded by Research Foundation - Flanders (FWO) as part of the Belgian contribution to LifeWatch.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': '6ac3f774-d9fb-4796-b3e9-92bf6c81c084',
#   'title': 'naturgucker',
#   'description': 'naturgucker.de / enjoynature.net is a rapidly growing social network with several millions of observations of wild plants and animals, thus naturgucker.de / enjoynature.net supports and promotes nature conservancy. naturgucker.de / enjoynature.net offers nature observers (mainly citizen scientists) a personal data center for their data in which they can pool and manage all their observations and nature photographs for the surrounding region, or even worldwide from their vacations. In addition, beginners can find a myriad of information, such as hundreds of thousands of photographs, up to date distribution maps, tenthousands observation areas with helpful hints, and a strong community in naturgucker.de /enjoaynature.net.',
#   'type': 'OCCURRENCE'},
#  {'key': '14d5676a-2c54-4f94-9023-1e8dcd822aa0',
#   'title': 'Pl@ntNet automatically identified occurrences',
#   'description': 'Pl&#64;ntNet is a participatory botanical observation platform allowing to identify plants from photos (using deep learning) and to share the observations with the community. The platform has three main front-ends: Pl&#64;ntNet androïd (http://bit.ly/1K4D1eU), Pl&#64;ntNet iOS (http://apple.co/2cMtWgu) and Pl&#64;ntNet web (https://identify.plantnet.org/). Pl&#64;ntNet was founded in 2010 by a consortium of four French research organisms (CIRAD, Inria, INRAE and IRD) and is now open to other members. More information about Pl&#64;ntNet can be found at https://plantnet.org/.  \n\nThe occurrences in this collection are Pl&#64;ntNet observations that have been identified only by the deep learning algorithm but which the algorithm confidence was sufficiently high to consider them as valid.',
#   'type': 'OCCURRENCE'},
#  {'key': 'f06fef3c-6ea6-4345-b724-a1b8e490dc55',
#   'title': 'Anillamiento SEO_Bird ringing',
#   'description': 'Scientific bird ringing is a research method based on the individual marking of birds.\nBird Ringing involves the marking of individual birds by highly trained ornithologists to provide vitaldata on migration patterns, demography\nand ecological processes.',
#   'type': 'OCCURRENCE'},
#  {'key': 'e6fab7b3-c733-40b9-8df3-2a03e49532c1',
#   'title': 'Flora von Deutschland (Phanerogamen)',
#   'description': 'Verbreitung der Farn- und Bluetenpflanzen in Deutschland, Vorkommensnachweise aggregiert auf Quadranten der Topographischen Karte 1 : 25000 (TK25 &#61; MTB), sowie in Zeitperioden , &lt;1950 - 1980&gt;, ',
#   'type': 'OCCURRENCE'},
#  {'key': '83fdfd3d-3a25-4705-9fbe-3db1d1892b13',
#   'title': 'Swiss National Databank of Vascular Plants',
#   'description': 'This dataset is maintained by Info Flora (National Data and Information Center of Swiss Flora), a member of Info Species. It includes records of vascular plants from Switzerland and the adjacent area. Data sources include field observations provided by a large network of volunteer collaborators, environmental impact studies, national inventories (Red List strategy), museum collections, literature and academic work. The period covered by the data extends from 1880 to the present day. All data provided have been subject to a validation procedure.',
#   'type': 'OCCURRENCE'},
#  {'key': '8ea4250e-0ff0-44f8-812e-bffc3b9ba2a4',
#   'title': 'Floristic records from survey studies of the Bayerisches Landesamt für Umwelt',
#   'description': 'http://wiki.bayernflora.de/web/Floristic_records_from_survey_studies_of_the_Bayerisches_Landesamt_f%C3%BCr_Umwelt',
#   'type': 'OCCURRENCE'},
#  {'key': '64dabd3c-4f34-4520-b9dd-d227a0bf1582',
#   'title': 'Occurrence Data of Vascular Plants collected or compiled for the Flora of Bavaria',
#   'description': 'https://wiki.bayernflora.de/web/Flora_of_Bavaria_%E2%94%80_occurrence_data_online',
#   'type': 'OCCURRENCE'},
#  {'key': 'fa7e6ad8-0a2e-49f2-b95d-e9f1e380fadf',
#   'title': 'Localización de táxones botánicos de interés para la identificación de hábitats de la REDIAM (Secretaría General de Medio Ambiente, Agua y Cambio Climático)',
#   'description': 'Localización de especies de flora andaluza procedente de la recopilación de diferentes contenidos de información disponibles en la REDIAM,siendo los principales: Mapa de usos y coberturas vegetales del suelo de Andalucía, 2007 (MUCVA2007); Cartografía y evaluación de la vegetación de la masa forestal de Andalucía (VEGE10); Inventario de árboles y arboledas singulares de Andalucía; Inventario y cartografía de los recursos etnobotánicos de Andalucía; Actuaciones gestionadas en EENNPP para el Plan de Recuperación de Artales en Andalucía; Estudio y conservación de las vides silvestres de Andalucía;Inventario, cartografía y caracterización de los Bosques Isla y Setos de Andalucía. Además se han incluido las localizaciones de especies disponibles en el Tercer Inventario Forestal Nacional (IFN3) (https://www.miteco.gob.es/es/biodiversidad/servicios/banco-datos-naturaleza/informacion-disponible/ifn3.aspx.',
#   'type': 'OCCURRENCE'},
#  {'key': '15f819bd-6612-4447-854b-14d12ee1022d',
#   'title': 'Naturalis Biodiversity Center (NL) - Botany',
#   'description': 'This database contains specimen records from the former herbarium of the Leiden University within the botanical collection of the Naturalis Biodiversity Center (Leiden, Netherlands). The Department of Botany houses the National Herbarium of the Netherlands (NHN) which consists of herbarium collections of the universities of Leiden, Wageningen and Utrecht. In 2010 the collection of the University of Amsterdam also moved to Naturalis.The focal areas of the collection are Southeast Asia, tropical America, tropical Africa and the Netherlands. The former herbarium of the Leiden University (acronym: L) contains about 4 million specimens and has extensive collections from Southeast Asia, especially from Indonesia and New Guinea, but it also holds a large collection of palearctic plants, and is the principle herbarium for Dutch plants. As the oldest Dutch herbarium, it also contains several historic collections.',
#   'type': 'OCCURRENCE'},
#  {'key': '07044577-bd82-4089-9f3a-f4a9d2170b2e',
#   'title': 'A global database for the distributions of crop wild relatives',
#   'description': 'This dataset originally held 5 647 442 total records, where 34% of the records corresponded to germplasm accessions and 66% to herbarium samples. A total of 3 231 286 records had cross-checked coordinates (see Figure 2). 322 735 records were newly georeferenced using The Google Geocoding API and 15 713 new records were obtained after digitizing the information contained in herbaria specimens. Data was gathered from more than 100 data providers, including GBIF (a comprehensive list of institutions and individuals is available here: http://www.cwrdiversity.org/data-sources/ ).\nThe geographic coverage of the dataset includes 96% of the world countries and also includes records of cultivated plants (1/3 of the dataset). Records of the crop wild relatives of 80 crop gene pools can be queried and visualized in this interactive map: http://www.cwrdiversity.org/distribution-map/\nThis dataset was assembled as part of the project ‘Adapting Agriculture to Climate Change: Collecting, Protecting and Preparing Crop Wild Relatives’, which is supported by the Government of Norway. The project is managed by the Global Crop Diversity Trust and the Millennium Seed Bank of the Royal Botanic Gardens, Kew, and implemented in partnership with national and international genebanks and plant breeding institutes around the world. For further information, please refer to the project website: http://www.cwrdiversity.org/\nFor publication to GBIF, all records originally gathered from GBIF have been removed to avoid data duplication.\nCitation: Crop Wild Relatives Occurrence data consortia ([year]). A global database for the distributions of crop wild relatives. Centro Internacional de Agricultura Tropical (CIAT). Occurrence dataset https://doi.org/10.15468/jyrthk accessed via GBIF.org on [date].',
#   'type': 'OCCURRENCE'},
#  {'key': '37f48e00-1fe8-11dc-b461-b8a03c50a862',
#   'title': 'Dutch Foundation for Applied Water Research (STOWA) - Limnodata Neerlandica',
#   'description': 'The Limnodata Neerlandica data set contains the data of more than 30 years systematic and project based sampling of Dutch, mainly freshwater, waterbodies. Data originate from 37 data providers; 26 water boards, the provinces and the Ministry of Transport, Public Works and Water Management. Over 20,000 sample points were used. The main purpose of the dataset is monitoring the quality of Dutch surface waters. Next to the biological characteristics also a-biotic data were sampled and stored alongside the biotic data. Observations are available from phytoplankton, diatoms, aquatic and riparian plants, macro-invertebrates and fish. The data were collected on a yearly base. The taxonomy has been validated according to the Dutch standardised checklist of aquatic species.\n\nUpdate January 2015: Added data for 2011 and 2012. Enhanced taxonomic and locality data fields.',
#   'type': 'OCCURRENCE'},
#  {'key': '857bce66-f762-11e1-a439-00145eb45e9a',
#   'title': 'Biologiezentrum Linz',
#   'description': 'ZOBODAT (Zoological Botanical Database)',
#   'type': 'OCCURRENCE'},
#  {'key': 'b05a19cf-dcf2-4ef9-bbbb-ad0ecbd2917c',
#   'title': 'Eremaea',
#   'type': 'OCCURRENCE'},
#  {'key': '20e3fcbb-c285-49ee-a93d-cc6ccd06ca9e',
#   'title': 'FLORIVON',
#   'description': 'Observations of vascular plants by botanists between 1902 and 1950 and a small number of published records and specimen data. Data have been collected in 1.3 x 1.01 km grid squares. The entire country of the Netherlands was surveyed.',
#   'type': 'OCCURRENCE'},
#  {'key': '95e635d4-f762-11e1-a439-00145eb45e9a',
#   'title': 'Banco de Datos de la Biodiversidad de la Comunitat Valenciana',
#   'description': 'El Banco de Datos de Biodiversidad de la Comunidad Valenciana, es la mayor plataforma virtual de recopilación de datos actuales sobre la distribución geográfica de las especies silvestres de la Comunidad Valenciana, que valida, por expertos en cada uno de los grupos taxonómicos y hace publicas todas las citas que son recogidas por la ciudadanía, investigadores e investigadoras, universidades, administraciones públicas y otros organismos de interés, para poder completar el conocimiento del estado de conservación de las especies silvestres que habitan la Comunidad Valenciana.',
#   'type': 'OCCURRENCE'},
#  {'key': 'bfc6fe18-77c7-4ede-a555-9207d60d1d86',
#   'title': 'Waarnemingen.be - Plant occurrences in Flanders and the Brussels Capital Region, Belgium',
#   'description': '<p>Waarnemingen.be - Plant occurrences in Flanders and the Brussels Capital Region, Belgium is a species occurrence dataset published by Natuurpunt and described (v1.4) in Steeman et al. (2017, https://doi.org/10.3897/phytokeys.85.14925). The dataset contains over 2.3 million plant occurrences of almost 1,300 naturally occurring species (native, vagrant or migrant species), recorded by volunteers (citizen scientists), mainly since 2008. Together with the datasets Van Landuyt &amp; Brosens (2017, http://www.gbif.org/dataset/271c444f-f8d8-4986-b748-e7367755c0c1) and Van Landuyt &amp; Noé (2015, https://doi.org/10.15468/xnlbke), the dataset represents the most complete overview of indigenous plants in Flanders and the Brussels Capital Region (north Belgium). The occurrences are derived from the database http://www.waarnemingen.be, hosted at the nature conservation NGO Natuurpunt in collaboration with Stichting Natuurinformatie. Standardized information regarding the occurrence&#39;s sex, reproductiveCondition, behavior, occurrenceRemarks, and samplingProtocol is included as well.</p>\n<p>Generalized and/or withheld information: location information is generalized to 4 x 4 km² IFBL grid cells. Observer name, exact XY-coordinates, toponyms, and photographs are not included in the published dataset, but are known in the source database.</p>\n<p>To allow anyone to use this dataset, we have released the data to the public domain under a Creative Commons Zero waiver (http://creativecommons.org/publicdomain/zero/1.0/). We would appreciate however, if you read and follow these norms for data use (http://www.natuurpunt.be/normen-voor-datagebruik) and provide a link to the original dataset (https://doi.org/10.15468/fyuklz) whenever possible. If you use these data for a scientific paper, please cite the dataset following the applicable citation norms and/or consider us for co-authorship. We are always interested to provide more information or know how you have used the data, so please contact us via the contact information provided in the metadata or natuurdata&#64;natuurpunt.be.</p>\n<p>The publication of this dataset is supported by INBO and funded by Research Foundation - Flanders (FWO) as part of the Belgian contribution to LifeWatch.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': 'b4ae1720-1431-49ee-bfeb-8146fc42b1a3',
#   'title': 'SAFRING: Historical Bird Ringing Records (2005-2009)',
#   'description': 'Bird ringing started in 1948 in southern Africa and is thus the longest running bird monitoring project in the sub-region. Although the data are biased to areas where ringers operated, it is an invaluable record of bird occurrence and distribution changes, arrival and departure times of migrants, survival and mass data in historical times.The South African Bird Ringing Unit (SAFRING), which is an essential arm of the Animal Demography Unit, administers bird ringing in southern Africa.',
#   'type': 'OCCURRENCE'},
#  {'key': 'c1492854-5d15-40e9-9ee7-24a18ac05112',
#   'title': 'Biodiversitätsdatenbank Salzburg',
#   'description': 'The Haus der Natur maintains a biodiversity database documenting the animal and plant species of Salzburg and adjacent areas (mainly). The database is growing continuousely and includes detailed information about the distribution of many groups of animals, fungi and plants. Special attention is given to the endangered species, threatened habitats, and protected areas of Salzburg. The database further contains global distribution data, mainly related to the museum&#39;s biological collection. All coordinates for gbif are rounded to two decimal places (approx. 1 km).',
#   'type': 'OCCURRENCE'},
#  {'key': '82ad4e4e-f762-11e1-a439-00145eb45e9a',
#   'title': 'Swiss National Butterflies and Forester Moths Databank',
#   'description': 'This dataset includes records of the butterflies (Papilionoidea: Hesperiidae, Lycaenidae, Nymphalidae, Papilionidae, Pieridae) and forester moths (Zygaenidae) from Switzerland and the adjacent area. Data sources include museum and private collections, the literature, field observations provided by a large network of volunteer collaborators, environmental impact studies, national inventories (Red List strategy, Biodiversity Monitoring)  and academic work. The period covered by the data extends from 1775 to the present day. All data provided have been subject to a validation procedure (http://www.cscf.ch/cscf/validation). Nomenclature largely follows Wiemers et al. (2018 : https://doi.org/10.3897/zookeys.811.28712) for butterflies, as well as SwissLepTeam (2010) for Zygaenidae.',
#   'type': 'OCCURRENCE'},
#  {'key': '355b8ff9-7bd9-49c3-92af-f6741b8bd0cb',
#   'title': 'LBBG_ZEEBRUGGE - Lesser black-backed gulls (Larus fuscus, Laridae) breeding at the southern North Sea coast (Belgium and the Netherlands) [subsampled representation]',
#   'description': '<p>This animal tracking dataset is derived from Stienen et al. (2022, <a href="https://doi.org/10.5281/zenodo.6579497">https://doi.org/10.5281/zenodo.6579497</a>) a deposit of Movebank study <a href="https://www.movebank.org/cms/webapp?gwt_fragment&#61;page&#61;studies,path&#61;study985143423">985143423</a>. Data have been standardized to Darwin Core using the <a href="https://inbo.github.io/movepub/">movepub</a> R package and are downsampled to the first GPS position per hour. The original dataset description follows.</p>\n<p><em>LBBG_ZEEBRUGGE - Lesser black-backed gulls (Larus fuscus, Laridae) breeding at the southern North Sea coast (Belgium and the Netherlands)</em> is a bird tracking dataset published by the <a href="https://www.inbo.be/en">Research Institute for Nature and Forest (INBO)</a>. It contains animal tracking data collected by the LifeWatch GPS tracking network for large birds (<a href="http://lifewatch.be/en/gps-tracking-network-large-birds">http://lifewatch.be/en/gps-tracking-network-large-birds</a>) for the project/study <strong>LBBG_ZEEBRUGGE</strong>, using trackers developed by the University of Amsterdam Bird Tracking System (UvA-BiTS, <a href="http://www.uva-bits.nl">http://www.uva-bits.nl</a>). The study has been operational since 2013. In total 162 individuals of Lesser black-backed gull (<em>Larus fuscus</em>) have been tagged in or near their breeding area at the southern North Sea coast (Zeebrugge and Ostend in Belgium and Vlissingen in the Netherlands), mainly to study their habitat use and migration behaviour. Data are periodically uploaded from the UvA-BiTS database to Movebank and from there archived on Zenodo (see <a href="https://github.com/inbo/bird-tracking">https://github.com/inbo/bird-tracking</a>).</p>\n<p>This dataset was collected using infrastructure provided by VLIZ and INBO funded by Research Foundation - Flanders (FWO) as part of the Belgian contribution to LifeWatch.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': '7a3679ef-5582-4aaa-81f0-8c2545cafc81',
#   'title': 'Pl@ntNet observations',
#   'description': 'Pl&#64;ntNet is a participatory botanical observation platform allowing to identify plants from photos (using deep learning) and to share the observations with the community. The platform has three main front-ends: Pl&#64;ntNet androïd (http://bit.ly/1K4D1eU), Pl&#64;ntNet iOS (http://apple.co/2cMtWgu) and Pl&#64;ntNet web (https://identify.plantnet.org/). Pl&#64;ntNet was founded in 2010 by a consortium of four French research organisms (CIRAD, Inria, INRAE and IRD) and is now open to other members. More information about Pl&#64;ntNet project can be found at https://plantnet.org/.  \n\nThe observations in this collection are the ones for which the authors agree to share the associated pictures under a creative common licence and for which the species name is considered as valid.',
#   'type': 'OCCURRENCE'},
#  {'key': 'd4aa2255-f927-4220-af22-2958298733b7',
#   'title': 'Sistema de Información de la vegetación Ibérica y Macaronésica',
#   'description': 'Observación florísticas procedentes de inventarios de vegetación. Estan informatizados aproximadamente el 70% de todos los datos Sistema de Información de la vegetación Ibérica y Macaronésica (http://www.sivim.info)',
#   'type': 'OCCURRENCE'},
#  {'key': 'a4b7c71e-fc73-434e-a008-d63c222179d0',
#   'title': 'FloraCAT: Banco de datos de los cormófitos de Cataluña',
#   'description': 'FloraCat es un banco de datos que recoge las observaciones sobre Cormófitos (pteridofitos, gimnosperamas y angiospermas) que a aparecen en la bibliografía especializada en el marco territorial de Cataluña. También se recoge la información taxonómica, ecológica, corológica, fitosociológica, etc., del taxón, siempre que estos datos figuren en el trabajo.',
#   'type': 'OCCURRENCE'},
#  {'key': '4cf3eec1-b902-40c9-b15b-05c5fe5928b6',
#   'title': 'CSIC-Real Jardín Botánico-Anthos. Sistema de Información de las Plantas de España',
#   'description': 'El Real Jardín Botánico ha desarrollado y mantenido diversas bases de datos sobre las plantas de la Península Ibérica. Uno de los proyectos que se desarrollaron en el RJB en la década de 1990 consistió en extraer de la literatura los datos de distribución de plantas. En 1999, cuando esta base de datos contaba con aproximadamente 600.000 registros, se continuó el trabajo a través del programa ANTHOS, financiado por la Fundación Biodiversidad (Ministerio de Agricultura, Alimentación y Medio Ambiente) y el Consejo Superior de Investigaciones Científicas - Real Jardín Botánico (Ministerio de Economía y Competitividad). Desde el año 2006 cuenta con una aplicación desarrollada sobre un sistema de información geográfica (SIG) que integra y mejora los procedimientos y consultas de la anterior, incrementa notablemente el conjunto de los datos disponibles —en la actualidad tenemos c. 1,8 millones—, hasta un horizonte de c. 3,5 millones de registros que estimamos para la bibliografía botánica de España. Además, la nueva aplicación combina la información corológica con otra de tipo cartográfico sobre variables ambientales y mapas de referencia, lo que permite localizar con mayor exactitud las citas de plantas, así como explicar de forma visual los patrones de distribución de las distintas especies. Se ha elegido como ámbito geográfico general del proyecto, la vista de la Península Ibérica e islas de la Macaronesia (Canarias, Madeira y Azores) como representación de las unidades biogeográficas presentes en España, de manera que se pueda estudiar la distribución de un taxon en todo el territorio nacional y zonas aledañas, e integrado en su componente geográfica.\nActualmente la información está también accesible a través del portal de colecciones del RJB (http://colecciones.rjb.csic.es/), con lo que conseguimos llegar aún a más usuarios.',
#   'type': 'OCCURRENCE'},
#  {'key': '1066dc76-6416-477a-a953-aec2bcd8de6b',
#   'title': 'Historical ringing data of birds with Polish rings',
#   'description': 'The Polish Ringing Centre was founded in 1931 to coordinate birds ringing in Poland. It collects and exchanges information about birds with Polish rings and ringed birds recovered in Poland. As a member of the European Union for Bird Ringing (EURING) it cooperates with other national ringing centres. So far, over 5 million records of birds marked with Polish rings have been collected in Polish Ringing Centre database, however, another hundreds of thousands need to be digitalised. This dataset contains the ringing data of birds ringed with Polish rings between 1950-1955 and 1967-2011.',
#   'type': 'OCCURRENCE'},
#  {'key': '52f2051b-c47e-403a-8e32-04b2f2273c20',
#   'title': 'Aranzadi Ringing Scheme (bird ring-recovery data)',
#   'description': 'This data base consists of bird ring-recovery data from the Aranzadi Ringing Scheme (Aranzadi Sciences Society, Spain). Data have been compiled since 1950. For each record, you will find the following information: species, locality (province, country, X and Y coordinates), catching method, and ring-recovery conditions and circumstances.',
#   'type': 'OCCURRENCE'},
#  {'key': 'cb850587-95f8-4ab1-83e4-a20267b3aea8',
#   'title': 'Flore Franco-Belge',
#   'description': 'La collecte de données a débuté en 1973. Le travail de terrain s&#39;est terminé en 1998.\n\nUn atlas a été publié par l&#39;Institut Floristique Franco-Belge en 2010.',
#   'type': 'OCCURRENCE'},
#  {'key': '3f4d4bf1-5f9a-43f2-a0d8-ff6ed5952796',
#   'title': 'IMOS - Animal Tracking Facility - Acoustic Tracking - Quality Controlled Detections (2007 -2021)',
#   'description': '<p>Over the last decade, the Integrated Marine Observing System’s Animal Tracking Facility (IMOS ATF) has established a permanent array of acoustic receivers around Australia to detect the movements of tagged marine animals in coastal waters. Simultaneously, IMOS ATF developed a centralised national database (https://animaltracking.aodn.org.au/) to encourage collaborative research across the user community and provide unprecedented opportunities to quantify individual behaviour across a broad range of taxa. Here we present the database and quality control procedures developed to collate 67 million valid detections from 1891 receiving stations. This dataset consists of detection data for 7800 tags deployed on 154 species (fish, sharks, rays, reptiles, and mammals), with distances traveled ranging from a few to thousands of kilometres. This dataset of acoustic detections constitutes a valuable resource facilitating meta-analysis of animal movement, distributions, and habitat use, and is important for relating species distribution shifts with environmental covariates.</p>\n<p>This copy of the IMOS ATF data is of the valid detections downloaded via the IMOS Animal Tracking Portal at https://animaltracking.aodn.org.au/detection. This dataset has been summarized by reducing the detection records to the count of detections per animal per site per day (UTC). The DwC field organismId has been used to record the transmitter serial number. The initial deployment/release of the animal has also been added to the dataset via EMoF using an occurrenceId of the transmitter tag with a postfix of &#39;-release&#39;. Parameters include transmitter type, length and weight of the released animal.</p>\n<p>Downloads of the detection, deployments and receiver stations are  from https://animaltracking.aodn.org.au/detection accessed in 2021-01-04</p>',
#   'type': 'OCCURRENCE'},
#  {'key': 'f9a70dab-004b-45ad-90cb-24d8ff645b44',
#   'title': 'Centre for Biodiversity Genomics - Canadian Specimens',
#   'description': 'The Centre for Biodiversity Genomics (CBG) at the University of Guelph is spearheading a novel approach to biodiversity research within Canada and internationally. Its three research units -- CBG Collections, CBG Genomics (or the Canadian Centre for DNA Barcoding, CCDB) and CBG Informatics -- are advancing 21st century biodiversity science by enabling species identification and discovery that is based on the analysis of sequence diversity in short, standardized gene regions, DNA barcodes. CBG Collections maintains a globally unique natural history collection of 3.3 million specimens. Every specimen is digitized, and the exact storage location of each specimen is tracked in a collection management information system for quick reference and retrieval. The databased information for every voucher is also archived in the Barcode of Life Data System (BOLD; www.boldsystems.org), permitting the permanent storage, validation and analysis of barcode sequence data and associated specimen metadata. Most (88.6%) of the specimens have been DNA barcoded, and a few representatives of every species have been digitally imaged. The CCDB holds high quality DNA extracts in a secure 2000 ft2 ultra-cold freezer bank. These DNA extracts reflect residual material following the barcode analysis of samples; it contains 5.3 million extracts from over 250,000 species derived from 231 countries, oceans and dependent territories, all connected to a voucher specimen on BOLD.\n\nThis resource represents the Canadian specimens held in the Specimen Archives of CBG Collections as of Dec 2017.  Please address inquiries to ccdbcol&#64;uoguelph.ca',
#   'type': 'OCCURRENCE'},
#  {'key': '87b6acb8-4db2-4769-93ca-e086040dfe14',
#   'title': 'Bugbase, Lepidopterological Society',
#   'description': 'Database on the recordings of Lepidoptera and Trichoptera by the Lepidopterological Society of Denmark (https://www.lepidoptera.dk). Occurrences are based on observations and collecting by any means, trapping, photos etc. Society specialist groups check data for errors and unusual records, mostly by contacting the observer/recorder. To assure quality of data, only members of the society are given access to enter records in the database.',
#   'type': 'OCCURRENCE'},
#  {'key': 'c779b049-28f3-4daf-bbf4-0a40830819b6',
#   'title': 'EBCC Atlas of European Breeding Birds',
#   'description': 'In 1997 the EBCC Atlas of European breeding birds, also referred to as European Ornithological Atlas or  &#39;EOA&#39;, was published. This voluminous book was the result of more than 25 years of fieldwork, cooperation, data gathering, data processing, writing and editing. Next to a beautiful book the data in the maps provides countless possibilities fur further studies on the distribution of the European breeding birds.',
#   'type': 'OCCURRENCE'},
#  {'key': 'bb5b30b4-827e-4d5e-a86a-825d65cb6583',
#   'title': 'Paleobiology Database',
#   'description': 'The Paleobiology Database (PBDB) is a non-governmental, non-profit public resource for paleontological data. It has been organized and operated by a multi-disciplinary, multi-institutional, international group of paleobiological researchers. Its purpose is to provide global, collection-based occurrence and taxonomic data for organisms of all geological ages, as well data services to allow easy access to data for independent development of analytical tools, visualization software, and applications of all types. The Database’s broader goal is to encourage and enable data-driven collaborative efforts that address large-scale paleobiological questions.',
#   'type': 'OCCURRENCE'},
#  {'key': 'f946666e-67dc-4848-9fa8-2162f3559e33',
#   'title': "Données d'occurrences Espèces issues de l'inventaire des ZNIEFF",
#   'description': 'Les données correspondent à des données de synthèse des espèces présentes dans les ZNIEFF. Les données sont bancarisées à la zone.',
#   'type': 'OCCURRENCE'},
#  {'key': '1f968e89-ca96-4065-91a5-4858e736b5aa',
#   'title': 'Waarnemingen.be - Butterfly occurrences in Flanders and the Brussels Capital Region, Belgium',
#   'description': '<p>Waarnemingen.be - Butterfly occurrences in Flanders and the Brussels Capital Region, Belgium is a species occurrence dataset published by Natuurpunt and described (v1.4) in Maes et al. (2016, https://doi.org/10.3897/zookeys.585.8019). The dataset contains close to 1.3 million butterfly (Lepidoptera excluding moths) occurrences of 69 naturally occurring species (native, vagrant or migrant species), recorded by volunteers (citizen scientists), mainly since 2008. Together with the dataset Maes et al. (2016, https://doi.org/10.15468/njgbmh), it represents the most complete overview of butterflies in Flanders and the Brussels Capital Region (north Belgium). The occurrences are derived from the database http://www.waarnemingen.be, hosted at the nature conservation NGO Natuurpunt in collaboration with Stichting Natuurinformatie. Standardized information regarding the occurrence&#39;s sex, lifeStage, behavior, occurrenceRemarks, and samplingProtocol is included as well.</p>\n<p>Generalized and/or withheld information: location information is generalized to 5 x 5 km² Universal Transverse Mercator (UTM) grid cells. Observer name, exact XY-coordinates, toponyms, and photographs are not included in the published dataset, but are known in the source database.</p>\n<p>To allow anyone to use this dataset, we have released the data to the public domain under a Creative Commons Zero waiver (http://creativecommons.org/publicdomain/zero/1.0/). We would appreciate however, if you read and follow these norms for data use (http://www.natuurpunt.be/normen-voor-datagebruik) and provide a link to the original dataset (https://doi.org/10.15468/ezfbee) whenever possible. If you use these data for a scientific paper, please cite the dataset following the applicable citation norms and/or consider us for co-authorship. We are always interested to provide more information or know how you have used the data, so please contact us via the contact information provided in the metadata or natuurdata&#64;natuurpunt.be.</p>\n<p>The publication of this dataset is supported by INBO and funded by Research Foundation - Flanders (FWO) as part of the Belgian contribution to LifeWatch.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': '43027054-3812-4599-b7bc-a01f1df5b071',
#   'title': 'Données ONF faune-flore-fonge',
#   'description': 'Données passées (reprise bibliographie et carnets de terrain; importations) et données actuelles depuis 2009 (BDN). A la fois données protocolées et données &#34;opportunistes&#34;.',
#   'type': 'OCCURRENCE'},
#  {'key': '31a35af0-c997-4f76-b045-9942bc14b896',
#   'title': 'USGS GAP - Alaska - Vertebrates - 1867-2009',
#   'description': 'The United States Geological Survey (USGS) Alaska Gap Analysis Project (GAP) compiles many smaller datasets of species occurrences to provide baseline information for conservation in Alaska, particularly when combined with other current efforts. These species occurrences (more than 1M occurrences for 300&#43; vertebrate species) were used with other ancillary data to generate distribution models and species range maps. The GAP models are among the first range-wide habitat models for vertebrate species at this resolution for Alaska. Prior to using Alaska GAP data, users are encouraged to become familiar with the GAP modeling process. These data provide researchers and managers with a tool for understanding the distribution of vertebrates within the context of these species habitats in Alaska.',
#   'type': 'OCCURRENCE'},
#  {'key': '8016518a-f762-11e1-a439-00145eb45e9a',
#   'title': 'Digitalización y Sistematización de las Colecciones Biológicas Nacionales del Instituto de Biología, UNAM (Plantas vasculares)',
#   'description': '<p>Esta propuesta constituye una primera etapa de una estrategia integral para digitalizar y actualizar la infraestructura y elevar el estatus curatorial de las colecciones biológicas nacionales resguardadas en el Instituto de Biología (IB) de la UNAM. En base a un diagnóstico del nivel curatorial y de digitalización de las colecciones, se plantea como objetivo general de esta primera etapa incrementar, en al menos un 35 %, el grado de digitalizacion de las colecciones botánicas (incluyendo las vivas y etnobiológicas del Jardín Botánico) y zoológicas del IB, mejorar su infraestructura y, a la par, depurar la información curatorial, tanto en los aspectos taxonómico y geográfico, como en el de imágenes. En virtud de que se tiene contemplado recuperar bases de datos de proyectos individuales previos apoyados por la CONABIO, al finalizar el proyecto se contará con una mejor perspectiva del grado de digitalización de las diversas colecciones que integran los acervos nacionales albergados en el IB. Además, se contará con dichas bases de datos en un formato digital uniforme de acuerdo con los estándares de la UNIBIO del IB, con especial atención en que sean compatibles con los acervos digitales de la propia CONABIO. Esta iniciativa abre una nueva etapa de conectividad académica entre el IB y la CONABIO, que propiciará una etapa de colaboración y enriquecimiento mutuo. Las bases de datos actualizadas constituirán un acervo digital significativo de la biodiversidad nacional, incluyendo registros con valor histórico, de manera que será posible realizar aproximaciones cronológicas sobre tendencias ambientales. Asimismo, el impacto en estrategias de conservación será relevante, ya que se facilitará dar respuesta a preguntas sobre suficiencia de muestreo en áreas naturales protegidas o en porciones del territorio nacional que requieran atención especial en los diversos taxones. A la par, la información de los acervos del IB contribuirá a seleccionar puntos de remuestreo en busca de especies en estatus especial de conservación o especies conocidas por ejemplares únicos o sólo de localidades tipo. Aunque los registros serán primordialmente nacionales, se contará con registros de otros países, principalmente latinoamericanos, a partir de ejemplares presentes en las colecciones del IB; algunas bases de datos incluirán registros de instituciones externas al IB o al país. En síntesis, este esfuerzo y las bases de datos que se obtendrán o actualizarán, contribuirá significativamente a tener una aproximación fidedigna sobre el conocimiento de la distribución reciente, actual y futura de la biodiversidad mexicana.\nPalabras clave: México, taxonomía, biodiversidad, colecciones botánicas, colecciones zoológicas, colecciones vivas, colecciones etnobiológicas, acervos.</p>\n<p>Reino: 1\nFilo: 2\nClase: 4\nOrden: 82\nFamilia: 367\nGénero: 5034\nSubgénero: 35\nEspecie: 43892\nEpitetoinfraespecifico: 7428</p>',
#   'type': 'OCCURRENCE'},
#  {'key': 'ad0d1a24-e952-11e2-961f-00145eb45e9a',
#   'title': 'VegetWeb - Repositorium von Vegetationsaufnahmen',
#   'description': 'VegetWeb - Repositorium von Vegetationsaufnahmen aus Deutschland: Vorkommen von Pflanzenarten in den Aufnahmeflächen, zugeordnet zu MTB-Rasterfeldern - repository of vegetation plot data from germany, assigned to grid fields of TK25 map units (6 x 10 geographical minutes)',
#   'type': 'OCCURRENCE'},
#  {'key': 'aab0cf80-0c64-11dd-84d1-b8a03c50a862',
#   'title': 'Lund Botanical Museum (LD)',
#   'description': 'The scientific collections of Lund Universty Botanical Museum (Herbarium LD) comprise 2.5 million specimens divided into algae &amp; cyanobacteria (102 000), bryophytes (149 000), fungi (63 000), lichens (170 000) and vascular plants (2 000 000). The collections go back to the 18th century and represent more than 250 years of scientific research. Coverage is worldwide with particularly important collections from Sweden, Denmark, Norway, Finland, Greece, Turkey, North Africa, South Africa, Zimbabwe and Australia.',
#   'type': 'OCCURRENCE'},
#  {'key': '93c8cc03-30cf-474e-8173-dbe5a22a5d28',
#   'title': 'JNCC seabird distribution and abundance data (all trips) from ESAS database',
#   'description': 'Original provider:\nEuropean Seabirds at Sea\n\nDataset credits:\nJoint Nature Conservation Committee (United Kingdom)\nNederlands Instituut voor Onderzoek der Zee (the Netherlands)\nOrnis Consult (Denmark)\nNational Institute for Coastal and Marine Management/RIKZ (the Netherlands)\nNederlands Zeevogelgroep (the Netherlands)\nInstituut voor Bos- en Natuuronderzoek (the Netherlands)\nInstituut voor Natuur Behoud (Belgium)\nNational Environmental Research Institute (Denmark)\nNorsk Institutt for Naturforskning (Norway)\nVogelwarte Helgoland (Germany)\n\nAbstract:\nThe European Seabirds at Sea (ESAS) database was established in 1991 as a collaboration between individuals and institutes who had collected data on the distribution of seabirds and marine mammals in north-west European offshore areas. The most recent version of this database contains over two million records which were collected over 25 years.\n\nPurpose:\nThe founding aim of this project was to merge data from different collaborators and use these to publish an atlas depicting vulnerable concentrations of seabirds to oil pollution. Subsequently, these data have been used for a wide variety of research purposes. The collaboration has also developed and defined common standards in data capture, processing and storage.\n\nSupplemental information:\n[2020-10-01] The following invalid species names were corrected according to the Integrated Taxonomic Information System (ITIS).\nLarus ridibundus (176835) &#61;&gt; Chroicocephalus ridibundus (824041)\nCorvus monedula (179746) &#61;&gt; Coloeus monedula (916629)\nLittle Gull: Larus minutus (176840) &#61;&gt; Hydrocoloeus minutus (824065)\nLittle Tern: Sterna albifrons (176899) &#61;&gt; Sternula albifrons (824126)\nMediterranean Gull: Larus melanocephalus (176858) &#61;&gt; Ichthyaetus melanocephalus (824070)\nRed Phalarope: Phalaropus fulicaria (554376) &#61;&gt; Phalaropus fulicarius (176734)\nSandwich Tern: Sterna sandvicensis (176927) &#61;&gt; Thalasseus sandvicensis (176932)\nTurtles: Testudines (173749) &#61;&gt; Testudines (948936)\nPhylloscopus sibilatrix (179847) &#61;&gt; Phylloscopus sibillatrix (916708)\nSula bassanus (174711) &#61;&gt; Morus bassanus (174712)\nLarus sabini (176865) &#61;&gt; Xema sabini (176866)\nSaxicola torquata (554448) &#61;&gt; Saxicola torquatus (726114)\n\n[2015-03-24] A few records had a wrong animal count of zero. The value is replaced with a blank representing species presence only.\n\nThis dataset represents a subset of version 4.1 of the ESAS database, which is composed of three related tables. As some attributes from the original dataset are dropped in the public view, certain records may appear as duplicate observations. This, however, is not the case, as these records will have varying attribute values in the original database (e.g., age/plumage/behavior, etc.) and should therefore be treated as separate entities.<br /><br />\n\nSpecies notes:<br />\nSpecies EURING code 462 (noted [sp_obs] field in the dataset) is <i>Puffinus puffinus mauretanicus</i>. As ITIS doesn&#39;t register this species, it is represented as <i>Puffinus puffinus</i> (TSN 174555), instead.<br />\nSpecies EURING code 460 (noted the [sp_obs] field in the dataset) is <i>Puffinus puffinus</i> whose counterpart in ITIS is also <i>Puffinus puffinus</i> (TSN 174555).<br /><br />\n\nThis dataset includes multiple trips whose survey methods vary. Please consult the data provider for the proper use of the dataset.',
# ...
#   'type': 'OCCURRENCE'},
#  {'key': '7a25f7aa-03fb-4322-aaeb-66719e1a9527',
#   'title': 'LACM Vertebrate Collection',
#   'description': 'The Collection includes the Fish, Herpetology, Bird and Mammal Collections of the Natural History Museum of Los Angeles County. They are worldwide collections with greatest concentration in North and South America, Africa, the Pacific Ocean, and the Antarctic.',
#   'type': 'OCCURRENCE'},
#  {'key': '4d1b5fed-e12f-48e8-94cb-88cf80115dd1',
#   'title': 'Local floras of Russia: records from literature',
#   'description': '<p>This is a compilative dataset based upon digitisation and databasing of multiple references. The mission of this resource is to enable direct access to a large array of floristic data published in 1975-2021 in hardly available journals, serials, monographs, dissertations and technical reports written in Russian.</p>\n<p>Submit a new reference | Отправить новый источник: https://docs.google.com/forms/d/e/1FAIpQLSeZt1z6e4lbn7mr7NECkRYcRfO8n9KlCSnc-XmtuCkIcz7taQ/viewform?usp&#61;sf_link</p>\n<p>All records within one local flora have the same centroid coordinates and coordinate uncertainty in metres. As of April 20, 2022, the dataset includes full checklists for 1,573 localities (100&#43; records), partial checklists for 1,073 localities (10 to 99 records) and casual records from 371 localities (1 to 9 records). We mobilised data from 604 published sources with mean georeference accuracy 21,965 m.</p>\n<p>We are adding constantly new references. Data cleaning (orthography of original names, typos, OCR mistakes) is in progress.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': '262f8270-f9c2-4bc6-a562-8ed71c0790e6',
#   'title': 'Stuart M. Fullerton Collection of Arthropods (UCFC), University of Central Florida',
#   'description': 'Vouchered occurrence records for arthropods, primarily insects, from the Stuart M. Fullerton Collection of Arthropods at the University of Central Florida.',
#   'type': 'OCCURRENCE'},
#  {'key': '10e44c48-0839-4a20-86d5-f0e23ae2e366',
#   'title': 'Bee Biology and Systematics Laboratory',
#   'description': 'The Pollinating Insects -- Biology, Management and Systematics Research Unit (PIRU) was founded in the late 1940s as part of the alfalfa seed production unit.  We focus primarily on pollination research with bees.The mission of the Pollinating Insect - Biology, Management and Systematics Research Unit is the development of non-Apis bees, for example the alfalfa leafcutting bee and blue orchard bee, as crop pollinators.  Research emphasis areas include the development and improvement of management systems for bee populations, biological studies of bees, plant-pollination systems, and bee biosystematics.  Cross-pollinated crops not effectively pollinated by honey bees have been targeted for improved pollination management, and the candidacy of selected pollinator species continues to be evaluated.  Current research on established species, like the alfalfa leafcutting bee and blue orchard bee, is directed toward developing control programs for pests and diseases, improving management that will result in better bee health and demonstrating pollination efficacy and increased producer profitability on &#34;new&#34; crops.',
#   'type': 'OCCURRENCE'},
#  {'key': 'c4e1739b-e225-4773-b2ca-b9dd90846c62',
#   'title': 'New York City Street Tree Census - 2005',
#   'description': 'Citywide street tree data from the 2005 Street Tree Census, conducted partly by volunteers organized by NYC Parks &amp; Recreation. Trees were inventoried by address, and were collected from 2005-2006. Data collected includes tree species, diameter, condition.',
#   'type': 'OCCURRENCE'},
#  {'key': '5c2a93e4-4578-496c-9b61-edb9d72e8cbc',
#   'title': 'flora&fauna(NIBR)2019',
#   'description': 'Flora &amp; Fauna Resources of National Institute of Biological Resources',
#   'type': 'OCCURRENCE'},
#  {'key': 'a9e763c8-f674-4492-94a8-4fd4eb9342a5',
#   'title': 'Aarhus University Palm Transect Database',
#   'description': 'Data from 500 x 5m palm transects in tropical American forests recording all palm individuals and assigning them to growthclasses from seedlings to adults.\nAll palm records are geo-referenced to one 5 x 5m subunit of a transect.\nAdditional ecological data are recorded to suppport the data.',
#   'type': 'OCCURRENCE'},
#  {'key': 'f3f03cbf-1a01-4739-ae15-c1355b8c2dbf',
#   'title': 'Carnegie Museum of Natural History Herbarium',
#   'description': 'The Carnegie Museum herbarium (CM) has over 540,000 worldwide vascular plant specimens as well as the best representation in any herbarium of specimens from western Pennsylvania and the Upper Ohio Basin. CM holds the private herbarium of Hannibal and Tyrecca Davis containing 20,000 specimens with a concentration on Rubus (Rosaceae).',
#   'type': 'OCCURRENCE'},
#  {'key': 'fab4c599-802a-4bfc-8a59-fc7515001bfa',
#   'title': 'Tercer Inventario Forestal Nacional. Ministerio de Agricultura, Alimentación y Medio Ambiente (España/Spain)',
#   'description': '<p>Third national forest inventory carried out by the Service of Forest Inventory from 1997 to 2006 and published by the General Directorate of Natural Environment and Forestry Policy of the Ministry of Environment, Rural and Marine affairs. Based on field work and performed at province level. Iberian Peninsula and Balearic Islands: Datum ED50, UTM Projection, International Ellipsoid of 1924, HAYFORD 1909, Zone 30. Canary Islands: Datum WGS84, UTM Projection, Ellipsoid WGS84, Zone 28. 1:50.000-scale map. …Few plant names from the IFN3 considered synonyms of others accepted in Flora iberica/Anthos were replaced by the accepted ones whenever they were homotypic synonyms. Also the Flora Iberica/Anthos criterion was followed regarding the scientific names spelling or authorship. …More info about IFN3 in: http://www.magrama.gob.es/es/biodiversidad/servicios/banco-datos-naturaleza/informacion-disponible/ifn3.aspx</p>\n<p>Note: this dataset was previously orphaned. It has been rescued by ① extracting it from the GBIF.org index (see GBIF Download in External Data) and ② republishing it on this IPT data hosting centre as version 1.0.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': 'f519367d-6b9d-411c-b319-99424741e7de',
#   'title': 'FWS and USGS Joint Native Bee Laboratory (BIML)',
#   'description': '<p>Species occurrence records for native and non-native bees, wasps and other insects collected using mainly pan, malaise, and vane trapping; and insect netting methods in Canada, Mexico, the non-contiguous United States, U.S. Territories (specifically U.S. Virgin Islands), U.S. Minor Outlying Islands and other global locations with the bulk of the specimens coming from the Eastern United States often from Federal lands such as USFWS, NPS, DOD, USFS. Some records also contain notes regarding plants or substrates from which insects were collected or that were present and/or in flower at the time the insects were collected. Unless otherwise noted, taxonomic determinations (identifications) were completed by Sam Droege (USGS Eastern Ecological Science Center- EESC, Native Bee Laboratory) and Clare Maffei (USFWS, Inventory and Monitoring Branch).</p>\n<p>The EESC Native Bee Lab currently keeps only a small synoptic collection, rare and voucher specimens are deposited in the Smithsonian National Collection (NMNH) and widely distributed to other institutions for DNA, revisions, and augmentation of existing collections.   Surplus specimens are also made available to students to learn their identifications. Corrections to any of our determinations are always welcomed. Common species that are not in demand for surplus are usually destroyed and the pins recycled. Recent revisions to Lasioglossum, Ceratina, and to a much lesser extent Triepeolus and Epeolus and other small groups have rendered determinations prior to those revisions out of date for species involved in name changes and users should account for that during analyses.  Current data (included information on specimen codes without identifications) are always available without charge directly from Sam Droege.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': '36f15a36-6b45-442e-9c31-cd633423aee0',
#   'title': 'Field Museum of Natural History (Zoology) Bird Collection',
#   'description': 'The Division of Birds houses the third largest scientific bird collection in the United States. The main collection contains over 480,000 specimens, including 600 holotypes, 70,000 skeletons, and 7,000 fluid specimens. In addition, the division houses 21,000 egg sets and 200 nests. The scope of the collection is world-wide; all bird families but one are represented, as are 90% of the world&#39;s genera and species. Included among its many historically and scientifically valuable individual collections are the H. B. Conover Game Bird Collection, Good&#39;s and Van Someren&#39;s African collections, C. B. Cory&#39;s West Indian collection, the Bishop Collection of North American birds, a large portion of W. Koelz&#39;s material from India and the Middle East, and many separate collections from South America, Africa (Hoogstraal from Egypt) and the Philippines (Rabor).',
#   'type': 'OCCURRENCE'},
#  {'key': 'ab47c4a9-4b6a-4d59-b846-899d9420f7d3',
#   'title': 'CRBPO : STOC, Baguage',
#   'description': 'Suivi temporel des oiseaux communs / Vigie Nature. http://vigienature.mnhn.fr/page/suivi-temporel-des-oiseaux-communs-stoc',
#   'type': 'OCCURRENCE'},
#  {'key': '45f54678-54ac-4468-8aac-bc83722fc768',
#   'title': 'MICA - Muskrat and coypu occurrences collected by UVW in the Netherlands',
#   'description': '<p>MICA - Muskrat and coypu occurrences collected by UVW in the Netherlands is an occurrence dataset published by the Research Institute of Nature and Forest (INBO) and the Netherlands Biodiversity Information Facility (NLBIF). It is part of the LIFE project MICA, in which innovative techniques are tested for a more efficient control of muskrat and coypu populations, both invasive species. This dataset contains muskrat and coypu counts. Here it is published as a standardized Darwin Core Archive and includes for each occurrence record an occurrenceID, date, location, the number of recorded individuals, status (present/absent) and scientific name. Issues with the dataset can be reported at https://github.com/inbo/mica-occurrences/issues</p>\n<p>We have released this dataset to the public domain under a Creative Commons Zero waiver. We would appreciate it if you follow the INBO norms for data use (https://www.inbo.be/en/norms-data-use) when using the data. If you have any questions regarding this dataset, don&#39;t hesitate to contact us via the contact information provided in the metadata or via opendata&#64;inbo.be.</p>\n<p>The data were collected as part of the MICA project, which received funding from the European Union’s LIFE Environment sub-programme under the grant agreement LIFE18 NAT/NL/001047.</p>',
#   'type': 'OCCURRENCE'},
#  {'key': 'e1e16cf0-ada2-11e2-8fbc-00145eb45e9a',
#   'title': 'Neptune Deep-Sea Microfossil Occurrence Database',
#   'description': 'Micropaleontologic study of deep-sea sediments cored over several decades by the DSDP, ODP and IODP drilling programs has yielded a vast body of information on the occurrences of individual fossil marine plankton species over time. This information also has been combined with other types of geochronologic information by interdisciplinary teams of scientists to construct detailed age estimates - age models - for hundreds of deep-sea drilling sections. Together, this information provides a uniquely detailed history of of biologic evolution in the oceans, as well as an important source of geochronologic information for geologic studies of ocean and climate change.    The Neptune database provides integrated access to this global data-set. It contains over 500,000 records for the occurrences of species in individual, numerically age-dated samples, age models for hundreds of deep-sea sections, and extensive, annotated, quality-controlled taxonomic lists for thousands of fossil marine plankton species. Neptune, or analyses from it, have been used in over 30 research papers (median ISI 3.5), including 8 in Science, Nature or PNAS.    Neptune was originally created by a team led by me in the early 1990s at the ETH in Zürich, and re-cast in internet form, with the addition of more data, by the Chronos project of NSF in the early 2000s. In response to the lapse of Chronos and support for Neptune, I teamed up with Patrick Diver, the main Chronos database programmer, to create a new version of Neptune (Neptune Sandbox Berlin, or NSB) that is hosted at the Museum für Naturkunde. Extensive reprogramming has streamlined the system so that it is easier to maintain, and includes support for direct programmable access over the internet for advanced research purposes. This project was supported by CEES, Oslo. NSB currently does not have a web-interface but one is planned to be added by early 2013.    NSB has already been used in published research within my own group, and to provide data on request to external scientists. Broader collaborations and renewed general public access via the web interface are planned for the future.',
#   'type': 'OCCURRENCE'},
#  {'key': '3942a8dc-9f01-420d-a829-01675dc01c73',
#   'title': '500,000 plant Specimens from PE Herbarium in China from 1950 to 1999',
#   'description': '500,000 plant Specimens from PE Herbarium in China from 1950 to 1999',
#   'type': 'OCCURRENCE'},
#  {'key': '84ab7b76-f762-11e1-a439-00145eb45e9a',
#   'title': 'C.A. Triplehorn Insect Collection (OSUC), Ohio State University',
#   'type': 'OCCURRENCE'},
#  {'key': '82ae8174-f762-11e1-a439-00145eb45e9a',
#   'title': 'Swiss National Dragonflies Databank',
#   'description': 'This dataset includes records of the Odonata (Aeshnidae, Calopterygidae, Coenagrionidae, Cordulegastridae, Corduliidae, Gomphidae, Lestidae, Libellulidae, Platycnemididae) from Switzerland. Data sources include museum and private collections, the literature, field observations provided by a large network of volunteer collaborators, environmental impact studies, national inventories (Red List strategy) and academic work. The period covered by the data extends from XVIIIth century to the present day. All data provided have been subject to a validation procedure (http://www.cscf.ch/cscf/validation).',
#   'type': 'OCCURRENCE'},
#  {'key': 'cca13f2c-0d2c-4c2f-93b9-4446c0cc1629',
#   'title': 'BugGuide - Identification, Images, & Information For Insects, Spiders & Their Kin For the United States & Canada',
#   'description': 'BugGuide (http://bugguide.net) is an online community of naturalists who enjoy learning about and sharing observations of insects, spiders, and other related creatures. BugGuide collects photographs of insects and other arthropods from the United States and Canada for identification and research and summarizes findings in guide pages for each order, family, genus, and species. By capturing the place and time that submitted images were taken, BugGuide creates a virtual insect collection.',
#   'type': 'OCCURRENCE'},
#  {'key': '82afb86e-f762-11e1-a439-00145eb45e9a',
#   'title': 'Swiss National Grasshoppers Databank',
#   'description': 'This dataset includes records of the Orthoptera and Mantodea (Acrididae, Gryllidae, Gryllotalpidae, Rhaphidophoridae, Tetrigidae, Tettigoniidae, Mantis religiosa) from Switzerland. Data sources include museum and private collections, the literature, field observations provided by a large network of volunteer collaborators, environmental impact studies, national inventories (Red List strategy) and academic work. The period covered by the data extends from XVIIIth century to the present day. All data provided have been subject to a validation procedure (http://www.cscf.ch/cscf/validation).',
#   'type': 'OCCURRENCE'}]

# %%
occurrences.download(['taxonKey = 121'], user='tusharlaksh', pwd='Cheeselord03!', email='tusharlaksh@gmail.com')
# Out:
# INFO:Your download key is 0187032-230224095556074
# ('0187032-230224095556074',
#  {'creator': 'tusharlaksh',
#   'notification_address': ['tusharlaksh@gmail.com'],
#   'sendNotification': True,
#   'predicate': {'type': 'and',
#    'predicates': [{'type': 'equals', 'key': 'TAXON_KEY', 'value': '121'}]}})

# %%
occurrences.download_get('0187032-230224095556074', path='')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [46], in <module>
# ----> 1 occurrences.download_get('0187032-230224095556074')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pygbif\occurrences\download.py:454, in download_get(key, path, **kwargs)
#     452 meta = occurrences.download_meta(key)
#     453 if meta["status"] != "SUCCEEDED":
# --> 454     raise Exception('download "%s" not of status SUCCEEDED' % key)
#     455 else:
#     456     logging.info("Download file size: %s bytes" % meta["size"])
#
# Exception: download "0187032-230224095556074" not of status SUCCEEDED
