# %%
import pandas as pd
import fathomnet.api
import os

# %%
path = r"D:\\Databases\\South African Institute for Aquatic Biodiversity - Elasmobranchii\\South African Institute for Aquatic Biodiversity - Elasmobranchii.xlsx"

# %%
occdf = pd.read_excel(path, 'occurrence')
mediadf = pd.read_excel(path, 'multimedia')

# %%
occdf = occdf.dropna(how='all', axis = 1)
mediadf = mediadf.dropna(how='all', axis = 1)

# %% [markdown]
# ### MAIN GOAL: Combine multimedia and occurrence data, make it upload-ready with available data
# - Primary Data:
#  - concept: Scientific Name, Class
#    - Scientific name preferred
#  - url: Image URL
#  - x: Bounding box X Coord
#  - y: Bounding box Y Coord
#  - width: Bounding Box Width (px)
#  - height: Bounding Box Height (px)
#
#
# - Optional Data
#  - altitude
#    - m
#  - altconcept: Secondary name for localization
#  - depth
#    - m
#  - groupof: If box contains multiple or singular entity
#    - TRUE/FALSE
#  - imagingtype: Any specialized imaging systems
#  - latitude
#    - Btwn -90S to 90N
#  - longitude
#    - Btwn -180W to 180E
#  - observer: Name of person or program who created the localization
#  - occluded: If object is occluded by another in an image
#    - TRUE/FALSE
#  - oxygen: O2 concentration
#    - ml/L
#  - pressure
#    - dbar
#  - salinity
#  - temperature
#    - Celsius
#  - timestamp
#    - ISO 8601 format
#  - truncated: If object extends beyond boundary of image
#    - TRUE/FALSE
#  - uderdefinedkey: UUID
#  - Any additional columns are added as key-value tags
#
#
#
# ### 2nd GOAL: Integrate Pythia into code, can try and upload directly from link in multimedia CSV, read bounding box results from website and put the box coordinates into csv
# - For larger image sets, use integrated models to create bounding boxes
# - https://colab.research.google.com/github/fathomnet/fathomnet-py/blob/main/tutorial.ipynb#scrollTo=jrTNntfuGRLQ (use as referece)

# %%
# Out:
#          gbifID                              identifier language    license  \
# 0    2849474115    90daf926-f93a-4c48-a46f-959261053622       en  CC_BY_4_0
# 1    1265270264  {FEA5AB03-5D08-4153-B6C8-0024626AC33D}       en  CC_BY_4_0
# 2    1265270263  {FE9BCB0F-A5FD-4E76-8610-0966B08A48F5}       en  CC_BY_4_0
# 3    1265270240  {FCDED75F-6D01-41FC-BA7E-A7C5AC9FC730}       en  CC_BY_4_0
# 4    1265270231  {FB78730B-0F09-4861-81FA-B5EAD3BB38C5}       en  CC_BY_4_0
# ..          ...                                     ...      ...        ...
# 743  1230327523    2328108d-fc21-11e2-ac3f-081965b14959       en  CC_BY_4_0
# 744  1230325905    23083e40-fc21-11e2-ac3f-081965b14959       en  CC_BY_4_0
# 745  1230325539    22ffd949-fc21-11e2-ac3f-081965b14959       en  CC_BY_4_0
# 746  1230324396    22e9fe03-fc21-11e2-ac3f-081965b14959       en  CC_BY_4_0
# 747  1230323901    22dc85a7-fc21-11e2-ac3f-081965b14959       en  CC_BY_4_0
#
#                modified rightsHolder            type  \
# 0   2019-07-03 04:25:46        SAIAB  PhysicalObject
# 1   2013-12-29 06:07:12        SAIAB           Event
# 2   2013-12-28 06:07:12        SAIAB           Event
# 3   2013-12-28 06:07:12        SAIAB           Event
# 4   2013-12-28 06:07:12        SAIAB           Event
# ..                  ...          ...             ...
# 743 2012-12-19 03:29:26        SAIAB  PhysicalObject
# 744 2009-10-08 04:33:19        SAIAB  PhysicalObject
# 745 2021-12-15 12:22:32        SAIAB  PhysicalObject
# 746 2018-05-09 10:26:02        SAIAB  PhysicalObject
# 747 2012-02-07 04:22:39        SAIAB  PhysicalObject
#
#                      institutionID  \
# 0    urn:lsid:biocol.org:col:34984
# 1    urn:lsid:biocol.org:col:34984
# 2    urn:lsid:biocol.org:col:34984
# 3    urn:lsid:biocol.org:col:34984
# 4    urn:lsid:biocol.org:col:34984
# ..                             ...
# 743  urn:lsid:biocol.org:col:34984
# 744  urn:lsid:biocol.org:col:34984
# 745  urn:lsid:biocol.org:col:34984
# 746  urn:lsid:biocol.org:col:34984
# 747  urn:lsid:biocol.org:col:34984
#
#                                           collectionID institutionCode  ...  \
# 0    http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 1    http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 2    http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 3    http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 4    http://grscicoll.org/institutional-collection/...           SAIAB  ...
# ..                                                 ...             ...  ...
# 743  http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 744  http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 745  http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 746  http://grscicoll.org/institutional-collection/...           SAIAB  ...
# 747  http://grscicoll.org/institutional-collection/...           SAIAB  ...
#
#     repatriated level0Gid    level0Name level1Gid    level1Name  level2Gid  \
# 0           1.0       NaN           NaN       NaN           NaN        NaN
# 1           0.0       NaN           NaN       NaN           NaN        NaN
# 2           0.0       NaN           NaN       NaN           NaN        NaN
# 3           0.0       NaN           NaN       NaN           NaN        NaN
# 4           0.0       NaN           NaN       NaN           NaN        NaN
# ..          ...       ...           ...       ...           ...        ...
# 743         1.0       NaN           NaN       NaN           NaN        NaN
# 744         0.0       ZAF  South Africa   ZAF.1_1  Eastern Cape  ZAF.1.8_1
# 745         1.0       NaN           NaN       NaN           NaN        NaN
# 746         1.0       NaN           NaN       NaN           NaN        NaN
# 747         1.0       NaN           NaN       NaN           NaN        NaN
#
#     level2Name    level3Gid              level3Name iucnRedListCategory
# 0          NaN          NaN                     NaN                  CR
# 1          NaN          NaN                     NaN                  VU
# 2          NaN          NaN                     NaN                  VU
# 3          NaN          NaN                     NaN                  LC
# 4          NaN          NaN                     NaN                  NE
# ..         ...          ...                     ...                 ...
# 743        NaN          NaN                     NaN                  NE
# 744  O.R.Tambo  ZAF.1.8.1_1  King Sabata Dalindyebo                  VU
# 745        NaN          NaN                     NaN                  NT
# 746        NaN          NaN                     NaN                  LC
# 747        NaN          NaN                     NaN                  NE
#
# [748 rows x 104 columns]
